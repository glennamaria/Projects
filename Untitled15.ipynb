# %% [markdown]
# <a href="https://colab.research.google.com/github/glennamaria/task1/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.8/dist-packages (2.0.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/lllll.csv',index_col='Year',parse_dates=True)
df=df.dropna()
print('Shape of data',df.shape)
df.head()
# Out:
# Shape of data (16, 21)
#                 Country      Status  Life expectancy   Adult Mortality  \
# Year
# 2000-01-01  Afghanistan  Developing              54.8              321
# 2001-01-01  Afghanistan  Developing              55.3              316
# 2002-01-01  Afghanistan  Developing              56.2                3
# 2003-01-01  Afghanistan  Developing              56.7              295
# 2004-01-01  Afghanistan  Developing              57.0              293
#
#             infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Year
# 2000-01-01             88     0.01               10.424960           62
# 2001-01-01             88     0.01               10.574728           63
# 2002-01-01             88     0.01               16.887351           64
# 2003-01-01             87     0.01               11.089053           65
# 2004-01-01             87     0.02               15.296066           67
#
#             Measles    BMI   ...  Polio  Total expenditure  Diphtheria   \
# Year                         ...
# 2000-01-01      6532   12.2  ...     24               8.20           24
# 2001-01-01      8762   12.6  ...     35               7.80           33
# 2002-01-01      2486   13.0  ...     36               7.76           36
# 2003-01-01       798   13.4  ...     41               8.82           41
# 2004-01-01       466   13.8  ...      5               8.79            5
#
#              HIV/AIDS         GDP  Population   thinness  1-19 years  \
# Year
# 2000-01-01        0.1  114.560000      293756                    2.3
# 2001-01-01        0.1  117.496980     2966463                    2.1
# 2002-01-01        0.1  187.845950    21979923                   19.9
# 2003-01-01        0.1  198.728544     2364851                   19.7
# 2004-01-01        0.1  219.141353    24118979                   19.5
#
#              thinness 5-9 years  Income composition of resources  Schooling
# Year
# 2000-01-01                  2.5                            0.338        5.5
# 2001-01-01                  2.4                            0.340        5.9
# 2002-01-01                  2.2                            0.341        6.2
# 2003-01-01                 19.9                            0.373        6.5
# 2004-01-01                 19.7                            0.381        6.8
#
# [5 rows x 21 columns]

# %%
df['Life expectancy '].plot(figsize=(12,5))

# %%
from statsmodels.tsa.stattools import adfuller

#perform augmented Dickey-Fuller test
adfuller(df['Life expectancy '])
# Out:
# (1.5962039886007395,
#  0.9978461425992515,
#  6,
#  9,
#  {'1%': -4.473135048010974,
#   '5%': -3.28988060356653,
#   '10%': -2.7723823456790124},
#  21.564895273638168)

# %%
import warnings
from pmdarima import auto_arima
import warnings
warnings.filterwarnings("ignore")

# %%
from statsmodels.base.data import ModelData
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

model =pm.auto_arima(df['Life expectancy '],start_p=1, start_q=1,
                           max_p=3, max_q=3, trace=True ,
                          suppress_warnings=True)
model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=52.082, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=53.351, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=54.249, Time=0.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.377 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   16
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 -24.041
# Date:                Thu, 29 Dec 2022   AIC                             52.082
# Time:                        13:19:33   BIC                             53.498
# Sample:                    01-01-2000   HQIC                            52.067
#                          - 01-01-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.6800      1.488      0.457      0.648      -2.237       3.597
# sigma2         1.4443      1.068      1.352      0.176      -0.649       3.538
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                79.93
# Prob(Q):                              0.75   Prob(JB):                         0.00
# Heteroskedasticity (H):              50.50   Skew:                             3.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
print(df.shape)
train=df['Life expectancy '].iloc[:-8]
test=df['Life expectancy '].iloc[-8:]
print(train.shape,test.shape)
# Out:
# (16, 21)
# (8,) (8,)

# %%
import matplotlib.pyplot as plt

# %%
model.plot_diagnostics(figsize=(16,8))
plt.show()

# %% [markdown]
# Interpretation of plots in plot diagnostics
# Standardized residual: The residual errors seem to fluctuate around a mean of zero and have a uniform variance.
#
# Histogram: The density plot suggest normal distribution with mean slighlty shifted towards right.
#
# Theoretical Quantiles: Mostly the dots fall perfectly in line with the red line. Any significant deviations would imply the distribution is skewed.
#
# Correlogram: The Correlogram, (or ACF plot) shows the residual errors are not autocorrelated. The ACF plot would imply that there is some pattern in the residual errors which are not explained in the model. So we will need to look for more X’s (predictors) to the model.
#
# Overall, the model seems to be a good fit. So, let's use it to forecast.

# %%
test.mean()
# Out:
# 59.875

# %%
import statsmodels.api as sm

# %%
model = sm.tsa.arima.ARIMA(train, order=(0,1,0))
result = model.fit()

print(result.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       Life expectancy    No. Observations:                    8
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                  -4.610
# Date:                Thu, 29 Dec 2022   AIC                             11.221
# Time:                        13:19:34   BIC                             11.167
# Sample:                    01-01-2000   HQIC                            10.552
#                          - 01-01-2007
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.2186      0.140      1.559      0.119      -0.056       0.493
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.13   Jarque-Bera (JB):                 0.40
# Prob(Q):                              0.14   Prob(JB):                         0.82
# Heteroskedasticity (H):               0.04   Skew:                             0.57
# Prob(H) (two-sided):                  0.07   Kurtosis:                         2.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fc = result.forecast(8, alpha=0.05)

# %%
from sklearn.metrics import mean_absolute_error 
import math

# %%
mse = mean_squared_error(test, fc)
print('MSE: '+str(mse))
mae = mean_absolute_error(test, fc)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test, fc))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(fc - test)/np.abs(test))
print('MAPE: '+str(mape))
# Out:
# MSE: 9.739999999999998
# MAE: 2.375
# RMSE: 3.1208973068654466
# MAPE: 0.038631878734522215

# %%
df.head()
# Out:
#                 Country      Status  Life expectancy   Adult Mortality  \
# Year
# 2000-01-01  Afghanistan  Developing              54.8              321
# 2001-01-01  Afghanistan  Developing              55.3              316
# 2002-01-01  Afghanistan  Developing              56.2                3
# 2003-01-01  Afghanistan  Developing              56.7              295
# 2004-01-01  Afghanistan  Developing              57.0              293
#
#             infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Year
# 2000-01-01             88     0.01               10.424960           62
# 2001-01-01             88     0.01               10.574728           63
# 2002-01-01             88     0.01               16.887351           64
# 2003-01-01             87     0.01               11.089053           65
# 2004-01-01             87     0.02               15.296066           67
#
#             Measles    BMI   ...  Polio  Total expenditure  Diphtheria   \
# Year                         ...
# 2000-01-01      6532   12.2  ...     24               8.20           24
# 2001-01-01      8762   12.6  ...     35               7.80           33
# 2002-01-01      2486   13.0  ...     36               7.76           36
# 2003-01-01       798   13.4  ...     41               8.82           41
# 2004-01-01       466   13.8  ...      5               8.79            5
#
#              HIV/AIDS         GDP  Population   thinness  1-19 years  \
# Year
# 2000-01-01        0.1  114.560000      293756                    2.3
# 2001-01-01        0.1  117.496980     2966463                    2.1
# 2002-01-01        0.1  187.845950    21979923                   19.9
# 2003-01-01        0.1  198.728544     2364851                   19.7
# 2004-01-01        0.1  219.141353    24118979                   19.5
#
#              thinness 5-9 years  Income composition of resources  Schooling
# Year
# 2000-01-01                  2.5                            0.338        5.5
# 2001-01-01                  2.4                            0.340        5.9
# 2002-01-01                  2.2                            0.341        6.2
# 2003-01-01                 19.9                            0.373        6.5
# 2004-01-01                 19.7                            0.381        6.8
#
# [5 rows x 21 columns]

# %%
df6=df.drop(labels=['Country',	'Status', 'Diphtheria ', ' thinness 5-9 years', 'Income composition of resources'], axis=1)
df6
# Out:
#             Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# Year
# 2000-01-01              54.8              321             88     0.01
# 2001-01-01              55.3              316             88     0.01
# 2002-01-01              56.2                3             88     0.01
# 2003-01-01              56.7              295             87     0.01
# 2004-01-01              57.0              293             87     0.02
# 2005-01-01              57.3              291             85     0.02
# 2006-01-01              57.3              295             84     0.03
# 2007-01-01              57.5              295             82     0.02
# 2008-01-01              58.1              287             80     0.03
# 2009-01-01              58.6              281             77     0.01
# 2010-01-01              58.8              279             74     0.01
# 2011-01-01              59.2              275             71     0.01
# 2012-01-01              59.5              272             69     0.01
# 2013-01-01              59.9              268             66     0.01
# 2014-01-01              59.9              271             64     0.01
# 2015-01-01              65.0              263             62     0.01
#
#             percentage expenditure  Hepatitis B  Measles    BMI   \
# Year
# 2000-01-01               10.424960           62      6532   12.2
# 2001-01-01               10.574728           63      8762   12.6
# 2002-01-01               16.887351           64      2486   13.0
# 2003-01-01               11.089053           65       798   13.4
# 2004-01-01               15.296066           67       466   13.8
# 2005-01-01                1.388648           66      1296   14.2
# 2006-01-01               17.171518           64      1990   14.7
# 2007-01-01               10.910156           63      1141   15.2
# 2008-01-01               25.873925           64      1599   15.7
# 2009-01-01               56.762217           63      2861   16.2
# 2010-01-01               79.679367           66      1989   16.7
# 2011-01-01                7.097109           68      3013   17.2
# 2012-01-01               78.184215           67      2787   17.6
# 2013-01-01               73.219243           64       430   18.1
# 2014-01-01               73.523582           62       492   18.6
# 2015-01-01               71.279624           65      1154   19.1
#
#             under-five deaths   Polio  Total expenditure   HIV/AIDS  \
# Year
# 2000-01-01                 122     24               8.20        0.1
# 2001-01-01                 122     35               7.80        0.1
# 2002-01-01                 122     36               7.76        0.1
# 2003-01-01                 122     41               8.82        0.1
# 2004-01-01                 120      5               8.79        0.1
# 2005-01-01                 118     58               8.70        0.1
# 2006-01-01                 116     58               7.43        0.1
# 2007-01-01                 113     63               6.73        0.1
# 2008-01-01                 110     64               8.33        0.1
# 2009-01-01                 106     63               9.42        0.1
# 2010-01-01                 102     66               9.20        0.1
# 2011-01-01                  97     68               7.87        0.1
# 2012-01-01                  93     67               8.52        0.1
# 2013-01-01                  89     62               8.13        0.1
# 2014-01-01                  86     58               8.18        0.1
# 2015-01-01                  83      6               8.16        0.1
#
#                    GDP  Population   thinness  1-19 years  Schooling
# Year
# 2000-01-01  114.560000      293756                    2.3        5.5
# 2001-01-01  117.496980     2966463                    2.1        5.9
# 2002-01-01  187.845950    21979923                   19.9        6.2
# 2003-01-01  198.728544     2364851                   19.7        6.5
# 2004-01-01  219.141353    24118979                   19.5        6.8
# 2005-01-01   25.294130      257798                   19.3        7.9
# 2006-01-01  272.563770     2589345                   19.2        8.1
# 2007-01-01  369.835796    26616792                   19.0        8.4
# 2008-01-01  373.361116     2729431                   18.8        8.7
# 2009-01-01  445.893298      284331                   18.6        8.9
# 2010-01-01  553.328940     2883167                   18.4        9.2
# 2011-01-01   63.537231     2978599                   18.2        9.5
# 2012-01-01  669.959000     3696958                   17.9        9.8
# 2013-01-01  631.744976    31731688                   17.7        9.9
# 2014-01-01  612.696514      327582                   17.5       10.0
# 2015-01-01  584.259210    33736494                   17.2       10.1

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
shape=df6.shape
print("Dataset contains {} rows and {} columns".format(shape[0],shape[1]))
# Out:
# Dataset contains 16 rows and 16 columns

# %%
x=df6.iloc[:,1:12]
y=df6.iloc[:,0]

# %%
x
# Out:
#             Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# Year
# 2000-01-01              321             88     0.01               10.424960
# 2001-01-01              316             88     0.01               10.574728
# 2002-01-01                3             88     0.01               16.887351
# 2003-01-01              295             87     0.01               11.089053
# 2004-01-01              293             87     0.02               15.296066
# 2005-01-01              291             85     0.02                1.388648
# 2006-01-01              295             84     0.03               17.171518
# 2007-01-01              295             82     0.02               10.910156
# 2008-01-01              287             80     0.03               25.873925
# 2009-01-01              281             77     0.01               56.762217
# 2010-01-01              279             74     0.01               79.679367
# 2011-01-01              275             71     0.01                7.097109
# 2012-01-01              272             69     0.01               78.184215
# 2013-01-01              268             66     0.01               73.219243
# 2014-01-01              271             64     0.01               73.523582
# 2015-01-01              263             62     0.01               71.279624
#
#             Hepatitis B  Measles    BMI   under-five deaths   Polio  \
# Year
# 2000-01-01           62      6532   12.2                 122     24
# 2001-01-01           63      8762   12.6                 122     35
# 2002-01-01           64      2486   13.0                 122     36
# 2003-01-01           65       798   13.4                 122     41
# 2004-01-01           67       466   13.8                 120      5
# 2005-01-01           66      1296   14.2                 118     58
# 2006-01-01           64      1990   14.7                 116     58
# 2007-01-01           63      1141   15.2                 113     63
# 2008-01-01           64      1599   15.7                 110     64
# 2009-01-01           63      2861   16.2                 106     63
# 2010-01-01           66      1989   16.7                 102     66
# 2011-01-01           68      3013   17.2                  97     68
# 2012-01-01           67      2787   17.6                  93     67
# 2013-01-01           64       430   18.1                  89     62
# 2014-01-01           62       492   18.6                  86     58
# 2015-01-01           65      1154   19.1                  83      6
#
#             Total expenditure   HIV/AIDS
# Year
# 2000-01-01               8.20        0.1
# 2001-01-01               7.80        0.1
# 2002-01-01               7.76        0.1
# 2003-01-01               8.82        0.1
# 2004-01-01               8.79        0.1
# 2005-01-01               8.70        0.1
# 2006-01-01               7.43        0.1
# 2007-01-01               6.73        0.1
# 2008-01-01               8.33        0.1
# 2009-01-01               9.42        0.1
# 2010-01-01               9.20        0.1
# 2011-01-01               7.87        0.1
# 2012-01-01               8.52        0.1
# 2013-01-01               8.13        0.1
# 2014-01-01               8.18        0.1
# 2015-01-01               8.16        0.1

# %%
y
# Out:
# Year
# 2000-01-01    54.8
# 2001-01-01    55.3
# 2002-01-01    56.2
# 2003-01-01    56.7
# 2004-01-01    57.0
# 2005-01-01    57.3
# 2006-01-01    57.3
# 2007-01-01    57.5
# 2008-01-01    58.1
# 2009-01-01    58.6
# 2010-01-01    58.8
# 2011-01-01    59.2
# 2012-01-01    59.5
# 2013-01-01    59.9
# 2014-01-01    59.9
# 2015-01-01    65.0
# Name: Life expectancy , dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print("X_train:",x_train.shape)
print("X_test:",x_test.shape)
print("Y_train:",y_train.shape)
print("Y_test:",y_test.shape)
# Out:
# X_train: (12, 11)
# X_test: (4, 11)
# Y_train: (12,)
# Y_test: (4,)

# %%
linreg=LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(x_test)
y_pred
# Out:
# array([54.77, 60.99, 60.41, 53.99])

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})

# %%
pred_df
# Out:
#             Actual Value  Predicted Value  Difference
# Year
# 2001-01-01          55.3        54.771540    0.528460
# 2006-01-01          57.3        60.986990   -3.686990
# 2008-01-01          58.1        60.414945   -2.314945
# 2009-01-01          58.6        53.990570    4.609430

# %%
MSE = np.square(np.subtract(y_test,y_pred)).mean() 
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 3.1811545088653705

# %%
import pandas
from sklearn import linear_model

# %%
print("Intercept: ", linreg.intercept_)
print("Coefficients:")
list(zip(x, linreg.coef_))
# Out:
# Intercept:  158.60949782614497
# Coefficients:
# [('Adult Mortality', -0.006303154874943303),
#  ('infant deaths', -4.727047088307413),
#  ('Alcohol', 401.5981830051919),
#  ('percentage expenditure', 0.04018762374329987),
#  ('Hepatitis B', 0.5402475446407924),
#  ('Measles ', 6.534788347045684e-05),
#  (' BMI ', -2.335924948962595),
#  ('under-five deaths ', 2.617490812447822),
#  ('Polio', -0.05321638857764199),
#  ('Total expenditure', -1.6607431552693819),
#  (' HIV/AIDS', -1.2521893596864021e-26)]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=101)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
y_pred = np.array(y_pred)
y_test = np.array(y_test)

print(np.concatenate((y_pred.reshape(len(y_test),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[61.32 59.9 ]
#  [58.13 56.2 ]
#  [56.57 56.7 ]
#  [59.52 59.5 ]]

# %%
accuracy_score =  regressor.score(X_test,y_test)
print(accuracy_score)
# Out:
# 0.46368079869977685

# %%
MSE = np.square(np.subtract(y_test,y_pred)).mean() 
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 1.2015424461915754

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})

# %%
pred_df
# Out:
#    Actual Value  Predicted Value  Difference
# 0          59.9           61.324      -1.424
# 1          56.2           58.131      -1.931
# 2          56.7           56.566       0.134
# 3          59.5           59.518      -0.018
