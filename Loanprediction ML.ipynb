# %% [markdown]
# <a href="https://colab.research.google.com/github/glennamaria/task1/blob/main/Loanprediction%20ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
path="/content/drive/MyDrive/test.csv"
test= pd.read_csv(path)
test
# Out:
#    Sl.No  AGE  GENDER  LOAN AMT  TOTAL INST   IRR  DPD  NPA  CIBIL  NET INCOME
# 0    1    24      1     400000        72     24.0    0   1    767      23900
# 1    2    44      1     200000        36     24.0    0   1     -1      23600
# 2    3    31      1     500000        84     21.5    0   1    693      22000
# 3    4    26      1     500000        96     24.0    0   1     -1      59600
# 4    5    38      1     750000       120     20.5    0   1    757      70600
# 5    6    53      1     295000        36     24.0    0   1    709     139000
# 6    7    32      1     500000        72     21.0  300   0     -1      52400
# 7    8    37      1     500000        72     23.0  249   0    743      45000
# 8    9    32      1     450000        60     24.0  767   0    752      69000

# %%
path="/content/drive/MyDrive/train.csv"
train= pd.read_csv(path)
train
# Out:
#       Si.No  AGE  GENDER  LOAN AMT  TOTAL INST   IRR  DPD  NPA  CIBIL  \
# 0        1   40      1     500000        60     24.0   0    1    715
# 1        2   30      1     400000        60     23.5   0    1    734
# 2        3   33      0     500000        60     21.5  81    1    690
# 3        4   31      1     500000        72     20.5   0    1    699
# 4        5   32      1     500000       120     20.5   0    1    819
# ...     ...  ...     ...       ...         ...   ...  ...  ...    ...
# 2230  2231   21      0     950000        84     21.5   0    1    778
# 2231  2232   40      0     100000        60     20.5   0    1     -1
# 2232  2233   40      0     400000        60     20.5   0    1     -1
# 2233  2234   40      0     250000        48     23.5   0    1     -1
# 2234  2235   44      0     350000        60     24.0   0    1    655
#
#       NET INCOME
# 0        52500
# 1        41816
# 2       118300
# 3        53000
# 4        66700
# ...          ...
# 2230     -5600
# ...

# %%
pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
AV = AutoViz_Class()
AV.AutoViz(train)
# Out:
# Shape of your Data Set loaded: (2235, 10)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  6
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  2
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     10 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Si.No']
# ...

# %%
import pandas as pd
from scipy import stats



# Calculate point biserial correlation
correlation_coefficient, p_value = stats.pointbiserialr(train['NPA'], train['CIBIL'])

print("Point Biserial Correlation Coefficient:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# Point Biserial Correlation Coefficient: 0.02246440446562389
# P-value: 0.2884344722032055

# %%
train.shape
# Out:
# (2235, 10)

# %%
test.shape
# Out:
# (9, 10)

# %%
print("Columns: ", len(train.columns))
# Out:
# Columns:  10

# %%
loan_train_columns = train.columns
loan_train_columns
# Out:
# Index(['Si.No', 'AGE', 'GENDER', 'LOAN AMT', 'TOTAL INST', 'IRR', 'DPD', 'NPA',
#        'CIBIL', 'NET INCOME'],
#       dtype='object')

# %%
train.describe()
# Out:
#           Si.No         AGE        GENDER       LOAN AMT    TOTAL INST   \
# count  2235.000000  2235.000000  2235.000000  2.235000e+03  2235.000000
# mean   1118.000000    37.205817     0.663535  4.788456e+05    65.965996
# std     645.333247     9.217392     0.472606  3.029965e+05    21.651813
# min       1.000000    19.000000     0.000000  3.500000e+04    24.000000
# 25%     559.500000    30.000000     0.000000  3.000000e+05    60.000000
# 50%    1118.000000    37.000000     1.000000  4.000000e+05    60.000000
# 75%    1676.500000    44.000000     1.000000  5.000000e+05    72.000000
# max    2235.000000    65.000000     1.000000  5.000000e+06   120.000000
#
#            IRR          DPD          NPA         CIBIL      NET INCOME
# count  2235.000000  2235.000000  2235.000000  2235.000000  2.235000e+03
# mean     22.505951    54.090828     0.898881   463.374049  6.890829e+04
# std       1.775733   188.308634     0.301553   354.676959  6.265053e+05
# ...

# %%
test.describe()
# Out:
#          Sl.No      AGE     GENDER    LOAN AMT     TOTAL INST     IRR     \
# count  9.000000   9.000000    9.0        9.000000    9.000000   9.000000
# mean   5.000000  35.222222    1.0   455000.000000   72.000000  22.888889
# std    2.738613   9.038498    0.0   153622.914957   26.832816   1.474317
# min    1.000000  24.000000    1.0   200000.000000   36.000000  20.500000
# 25%    3.000000  31.000000    1.0   400000.000000   60.000000  21.500000
# 50%    5.000000  32.000000    1.0   500000.000000   72.000000  24.000000
# 75%    7.000000  38.000000    1.0   500000.000000   84.000000  24.000000
# max    9.000000  53.000000    1.0   750000.000000  120.000000  24.000000
#
#            DPD        NPA       CIBIL     NET INCOME
# count    9.000000  9.000000    9.000000       9.000000
# mean   146.222222  0.666667  490.888889   56122.222222
# std    261.691984  0.500000  369.641192   36493.347948
# min      0.000000  0.000000   -1.000000   22000.000000
# ...

# %%
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2235 entries, 0 to 2234
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Si.No       2235 non-null   int64
#  1   AGE         2235 non-null   int64
#  2   GENDER      2235 non-null   int64
#  3   LOAN AMT    2235 non-null   int64
#  4   TOTAL INST  2235 non-null   int64
#  5   IRR         2235 non-null   float64
#  6   DPD         2235 non-null   int64
#  7   NPA         2235 non-null   int64
#  8   CIBIL       2235 non-null   int64
#  9   NET INCOME  2235 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 174.7 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sl.No       9 non-null      int64
#  1   AGE         9 non-null      int64
#  2   GENDER      9 non-null      int64
# ...

# %%
def explore_object_type(df ,feature_name):

    if df[feature_name].dtype ==  'object':
        print(df[feature_name].value_counts())

# %%
for featureName in train:
    if train[featureName].dtype == 'object':
        print('\n"' + str(featureName) + '\'s" Values with count are :')
        explore_object_type(train, str(featureName))

# %%
import missingno as msno

# %%
train
train.isna().sum()
# round((loan_train.isna().sum() / len(loan_train)) * 100, 2)
# Out:
# Si.No         0
# AGE           0
# GENDER        0
# LOAN AMT      0
# TOTAL INST    0
# IRR           0
# DPD           0
# NPA           0
# CIBIL         0
# NET INCOME    0
# dtype: int64

# %%
msno.bar(train)
# Out:
# <Axes: title={'center': 'Average IRR by NPA (Top 20)'}>

# %%
msno.matrix(train )
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


import seaborn as sns
sns.set_style('dark')

# %%
train
# Out:
#       Si.No  AGE  GENDER  LOAN AMT  TOTAL INST   IRR  DPD  NPA  CIBIL  \
# 0        1   40      1     500000        60     24.0   0    1    715
# 1        2   30      1     400000        60     23.5   0    1    734
# 2        3   33      0     500000        60     21.5  81    1    690
# 3        4   31      1     500000        72     20.5   0    1    699
# 4        5   32      1     500000       120     20.5   0    1    819
# ...     ...  ...     ...       ...         ...   ...  ...  ...    ...
# 2230  2231   21      0     950000        84     21.5   0    1    778
# 2231  2232   40      0     100000        60     20.5   0    1     -1
# 2232  2233   40      0     400000        60     20.5   0    1     -1
# 2233  2234   40      0     250000        48     23.5   0    1     -1
# 2234  2235   44      0     350000        60     24.0   0    1    655
#
#       NET INCOME
# 0        52500
# 1        41816
# 2       118300
# 3        53000
# 4        66700
# ...          ...
# 2230     -5600
# ...

# %%
# import ml model from sklearn pacakge

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

# %%
logistic_model = LogisticRegression()

# %%
train_features = ['CIBIL', 'LOAN AMT', 'GENDER']

x_train = train[train_features].values
y_train = train['NPA'].values

x_test = test[train_features].values

# %%
print(type(x_train[0]))
# Out:
# <class 'numpy.ndarray'>

# %%
print(type(y_train[0]))
# Out:
# <class 'numpy.int64'>

# %%
logistic_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# Predict the model for testin data

predicted = logistic_model.predict(x_test)

# %%
# check the coefficeints of the trained model
print('Coefficient of model :', logistic_model.coef_)
# Out:
# Coefficient of model : [[1.72843987e-03 2.20430551e-06 2.57945814e-06]]

# %%
# check the intercept of the model
print('Intercept of model',logistic_model.intercept_)
# Out:
# Intercept of model [3.98088043e-06]

# %%
score = logistic_model.score(x_train, y_train)
print('accuracy_score overall :', score)
print('accuracy_score percent :', round(score*100,2))
# Out:
# accuracy_score overall : 0.8988814317673378
# accuracy_score percent : 89.89

# %%
predict_test = logistic_model.predict(x_test)
print('Target on test data',predict_test)
# Out:
# Target on test data [1 1 1 1 1 1 1 1 1]

# %%
print(predict_test)
# Out:
# [1 1 1 1 1 1 1 1 1]

# %%
predicted_probabilities = logistic_model.predict_proba(x_test)

# %%
path="/content/drive/MyDrive/Modelling.csv"
df= pd.read_csv(path)
df
# Out:
#          LoanID     LoanAmount          Name          Age  Gender  DPD  \
# 0     4.333500e+14    500000                 LAKSHMI  51   FEMALE   41
# 1     4.333500e+14    500000             JERLINKUMAR  29     MALE    0
# 2     4.331200e+14    500000             SWAMINATHAN  36     MALE  997
# 3     4.333500e+14    550000                JEEVITHA  37   FEMALE  997
# 4     4.333500e+14    400000              RENUGADEVI  45   FEMALE   47
# ...            ...         ...                   ...  ...     ...  ...
# 2323  4.347500e+14    400000            RAVADA PRIYA  42   FEMALE    0
# 2324  4.313600e+14    500000            JAKIRHUSSAIN  24     MALE    0
# 2325  4.338000e+14    100000    NIHAL RANJAN MOHANTY  27     MALE    0
# 2326  4.338000e+14    400000    NIHAL RANJAN MOHANTY  27     MALE    0
# 2327  4.123400e+14    210000                   OMANA  53   FEMALE    0
#
#      MaritalStatus            Employer             FamilyDependants  \
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
correlation_matrix = train.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd

# Assuming df is your DataFrame containing the two variables
correlation_coefficient = train['NPA'].corr(train['CIBIL'])
correlation_coefficient
# Out:
# 0.022464404465623814

# %%
from scipy.stats import f_oneway

category_groups = [group['CIBIL'] for name, group in df.groupby('Deliquency')]
f_stat, p_value = f_oneway(*category_groups)
f_stat, p_value
# Out:
# (2.874322946082438, 0.09013665714468026)
