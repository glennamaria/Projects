# %% [markdown]
# <a href="https://colab.research.google.com/github/glennamaria/task1/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/Life Expectancy Data.csv"
df= pd.read_csv(path)
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print(df.columns)
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# country                              0
# year                                 0
# status                               0
# life_expectancy                     10
# adult_mortality                     10
# infant_deaths                        0
# alcohol                            194
# percentage_expenditure               0
# hepatitis_b                        553
# measles                              0
# bmi                                 34
# under-five_deaths                    0
# polio                               19
# total_expenditure                  226
# diphtheria                          19
# hiv/aids                             0
# gdp                                448
# population                         652
# thinness__1-19_years                34
# thinness_5-9_years                  34
# income_composition_of_resources    167
# schooling                          163
# dtype: int64

# %%
country_list = df.country.unique()
interpolate_list =['life_expectancy', 'adult_mortality', 'infant_deaths', 'alcohol', 
                   'percentage_expenditure', 'hepatitis_b', 'measles', 'bmi', 'under-five_deaths', 
                   'polio', 'total_expenditure', 'diphtheria', 'hiv/aids', 'gdp', 'population', 
                   'thinness__1-19_years', 'thinness_5-9_years', 'income_composition_of_resources', 
                   'schooling']
for country in country_list:
    df.loc[df['country'] == country,interpolate_list] = df.loc[df['country'] == country,interpolate_list].interpolate()

# %%
df.isnull().sum()
# Out:
# country                              0
# year                                 0
# status                               0
# life_expectancy                     10
# adult_mortality                     10
# infant_deaths                        0
# alcohol                            193
# percentage_expenditure               0
# hepatitis_b                        144
# measles                              0
# bmi                                 34
# under-five_deaths                    0
# polio                                0
# total_expenditure                  211
# diphtheria                           0
# hiv/aids                             0
# gdp                                422
# population                         652
# thinness__1-19_years                34
# thinness_5-9_years                  34
# income_composition_of_resources    167
# schooling                          163
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#           country  year      status  life_expectancy  adult_mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant_deaths  alcohol  percentage_expenditure  hepatitis_b  measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  polio  total_expenditure  diphtheria  hiv/aids         gdp  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358878
#
#       population  thinness__1-19_years  thinness_5-9_years  \
# 0     33736494.0                  17.2                17.3
# 1       327582.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2933  12777511.0                   9.4                 9.4
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
# 2937  12222251.0                  11.0                11.2
#
#       income_composition_of_resources  schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [1987 rows x 22 columns]

# %%
df1=df.copy()
df1.to_csv('cleaned.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1987 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          1987 non-null   object
#  1   year                             1987 non-null   int64
#  2   status                           1987 non-null   object
#  3   life_expectancy                  1987 non-null   float64
#  4   adult_mortality                  1987 non-null   float64
#  5   infant_deaths                    1987 non-null   int64
#  6   alcohol                          1987 non-null   float64
#  7   percentage_expenditure           1987 non-null   float64
#  8   hepatitis_b                      1987 non-null   float64
#  9   measles                          1987 non-null   int64
#  10  bmi                              1987 non-null   float64
#  11  under-five_deaths                1987 non-null   int64
#  12  polio                            1987 non-null   float64
#  13  total_expenditure                1987 non-null   float64
#  14  diphtheria                       1987 non-null   float64
#  15  hiv/aids                         1987 non-null   float64
#  16  gdp                              1987 non-null   float64
#  17  population                       1987 non-null   float64
#  18  thinness__1-19_years             1987 non-null   float64
#  19  thinness_5-9_years               1987 non-null   float64
#  20  income_composition_of_resources  1987 non-null   float64
#  21  schooling                        1987 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 357.0+ KB

# %%
columns_dict={'life_expectancy': 1, 'adult_mortality': 2, 'infant_deaths': 3, 'alcohol': 4, 
                   'percentage_expenditure': 5, 'hepatitis_b': 6, 'measles': 7, 'bmi': 8, 'under-five_deaths': 9, 
                   'polio': 10, 'total_expenditure': 11, 'diphtheria': 12, 'hiv/aids': 13, 'gdp': 14, 'population': 15, 
                   'thinness__1-19_years': 16, 'thinness_5-9_years': 17, 'income_composition_of_resources': 18, 
                   'schooling':19}             
plt.figure(figsize=(20,30))
for variable,i in columns_dict.items():
  plt.subplot(5,4,i)
  plt.boxplot(df[variable])
  plt.title(variable)

plt.show()

# %%
df.describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count  1987.000000      1987.000000      1987.000000    1987.000000
# mean   2006.984902        67.981782       175.187217      36.623553
# std       4.323147         9.706401       131.616942     138.784913
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2003.000000        61.700000        75.000000       1.000000
# 50%    2007.000000        69.900000       153.000000       4.000000
# 75%    2011.000000        74.700000       243.000000      25.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            alcohol  percentage_expenditure  hepatitis_b        measles  \
# count  1987.000000             1987.000000   1987.00000    1987.000000
# mean      4.455644              685.492318     73.86160    2729.561651
# std       3.976733             1761.669050     29.02807   12102.389143
# min       0.010000                0.000000      2.00000       0.000000
# 25%       0.830000               29.469887     64.00000       0.000000
# 50%       3.770000              104.314473     86.00000      20.000000
# 75%       7.190000              470.870122     95.00000     499.500000
# max      17.870000            18961.348600     99.00000  212183.000000
#
#                bmi  under-five_deaths        polio  total_expenditure  \
# count  1987.000000        1987.000000  1987.000000        1987.000000
# mean     36.428636          50.932562    80.371917           5.902728
# std      19.736138         188.933117    24.363376           2.287467
# min       1.400000           0.000000     3.000000           0.370000
# 25%      18.150000           1.000000    74.000000           4.360000
# 50%      38.700000           4.000000    91.000000           5.800000
# 75%      55.000000          36.000000    96.000000           7.385000
# max      77.100000        2500.000000    99.000000          14.390000
#
#         diphtheria     hiv/aids            gdp    population  \
# count  1987.000000  1987.000000    1987.000000  1.987000e+03
# mean     80.454454     2.274937    5392.335709  1.358390e+07
# std      24.450153     6.005112   11480.810350  6.490113e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      75.500000     0.100000     384.553107  1.967480e+05
# 50%      91.000000     0.100000    1334.651896  1.396861e+06
# 75%      96.000000     1.400000    4441.530655  7.625918e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        thinness__1-19_years  thinness_5-9_years  \
# count           1987.000000         1987.000000
# mean               5.129995            5.199346
# std                4.750149            4.844382
# min                0.100000            0.100000
# 25%                1.600000            1.600000
# 50%                3.300000            3.400000
# 75%                7.600000            7.700000
# max               27.700000           28.600000
#
#        income_composition_of_resources    schooling
# count                      1987.000000  1987.000000
# mean                          0.603453    11.639054
# std                           0.206026     3.212964
# min                           0.000000     0.000000
# 25%                           0.473000     9.700000
# 50%                           0.648000    11.900000
# 75%                           0.745000    13.700000
# max                           0.936000    20.700000

# %%
def outlier_count(col, data=df):
    print(15*'-' + col + 15*'-')
    q75, q25 = np.percentile(data[col], [75, 25])
    iqr = q75 - q25
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    print('Number of outliers: {}'.format(outlier_count))
    print('Percent of data that is outlier: {}%'.format(outlier_percent))
for col in columns_dict:
    outlier_count(col)
# Out:
# ---------------life_expectancy---------------
# Number of outliers: 4
# Percent of data that is outlier: 0.2%
# ---------------adult_mortality---------------
# Number of outliers: 58
# Percent of data that is outlier: 2.92%
# ---------------infant_deaths---------------
# Number of outliers: 198
# Percent of data that is outlier: 9.96%
# ---------------alcohol---------------
# Number of outliers: 3
# Percent of data that is outlier: 0.15%
# ---------------percentage_expenditure---------------
# Number of outliers: 232
# Percent of data that is outlier: 11.68%
# ---------------hepatitis_b---------------
# Number of outliers: 216
# Percent of data that is outlier: 10.87%
# ---------------measles---------------
# Number of outliers: 361
# Percent of data that is outlier: 18.17%
# ---------------bmi---------------
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
# ---------------under-five_deaths---------------
# Number of outliers: 227
# Percent of data that is outlier: 11.42%
# ---------------polio---------------
# Number of outliers: 159
# Percent of data that is outlier: 8.0%
# ---------------total_expenditure---------------
# Number of outliers: 13
# Percent of data that is outlier: 0.65%
# ---------------diphtheria---------------
# Number of outliers: 195
# Percent of data that is outlier: 9.81%
# ---------------hiv/aids---------------
# Number of outliers: 309
# Percent of data that is outlier: 15.55%
# ---------------gdp---------------
# Number of outliers: 244
# Percent of data that is outlier: 12.28%
# ---------------population---------------
# Number of outliers: 260
# Percent of data that is outlier: 13.09%
# ---------------thinness__1-19_years---------------
# Number of outliers: 70
# Percent of data that is outlier: 3.52%
# ---------------thinness_5-9_years---------------
# Number of outliers: 75
# Percent of data that is outlier: 3.77%
# ---------------income_composition_of_resources---------------
# Number of outliers: 91
# Percent of data that is outlier: 4.58%
# ---------------schooling---------------
# Number of outliers: 32
# Percent of data that is outlier: 1.61%

# %%
for variable in columns_dict.keys():
    q75, q25 = np.percentile(df[variable], [75 ,25])
    iqr = q75 - q25

    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    print("Number of outliers and percentage of it in {} : {} and {}".format(variable,
                                                                             len((np.where((df[variable] > max_val) | 
                                                                                           (df[variable] < min_val))[0])),len((np.where((df[variable] > max_val) | 
                                                                                           (df[variable] < min_val))[0]))*100/1987))
# Out:
# Number of outliers and percentage of it in life_expectancy : 4 and 0.20130850528434827
# Number of outliers and percentage of it in adult_mortality : 58 and 2.9189733266230498
# Number of outliers and percentage of it in infant_deaths : 198 and 9.96477101157524
# Number of outliers and percentage of it in alcohol : 3 and 0.1509813789632612
# Number of outliers and percentage of it in percentage_expenditure : 232 and 11.675893306492199
# Number of outliers and percentage of it in hepatitis_b : 216 and 10.870659285354806
# Number of outliers and percentage of it in measles : 361 and 18.16809260191243
# Number of outliers and percentage of it in bmi : 0 and 0.0
# Number of outliers and percentage of it in under-five_deaths : 227 and 11.424257674886764
# Number of outliers and percentage of it in polio : 159 and 8.002013085052843
# Number of outliers and percentage of it in total_expenditure : 13 and 0.6542526421741318
# Number of outliers and percentage of it in diphtheria : 195 and 9.813789632611979
# Number of outliers and percentage of it in hiv/aids : 309 and 15.551082033215904
# Number of outliers and percentage of it in gdp : 244 and 12.279818822345245
# Number of outliers and percentage of it in population : 260 and 13.085052843482638
# Number of outliers and percentage of it in thinness__1-19_years : 70 and 3.5228988424760947
# Number of outliers and percentage of it in thinness_5-9_years : 75 and 3.77453447408153
# Number of outliers and percentage of it in income_composition_of_resources : 91 and 4.579768495218923
# Number of outliers and percentage of it in schooling : 32 and 1.6104680422747861

# %%
df.describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count  1987.000000      1987.000000      1987.000000    1987.000000
# mean   2006.984902        67.981782       175.187217      36.623553
# std       4.323147         9.706401       131.616942     138.784913
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2003.000000        61.700000        75.000000       1.000000
# 50%    2007.000000        69.900000       153.000000       4.000000
# 75%    2011.000000        74.700000       243.000000      25.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            alcohol  percentage_expenditure  hepatitis_b        measles  \
# count  1987.000000             1987.000000   1987.00000    1987.000000
# mean      4.455644              685.492318     73.86160    2729.561651
# std       3.976733             1761.669050     29.02807   12102.389143
# min       0.010000                0.000000      2.00000       0.000000
# 25%       0.830000               29.469887     64.00000       0.000000
# 50%       3.770000              104.314473     86.00000      20.000000
# 75%       7.190000              470.870122     95.00000     499.500000
# max      17.870000            18961.348600     99.00000  212183.000000
#
#                bmi  under-five_deaths        polio  total_expenditure  \
# count  1987.000000        1987.000000  1987.000000        1987.000000
# mean     36.428636          50.932562    80.371917           5.902728
# std      19.736138         188.933117    24.363376           2.287467
# min       1.400000           0.000000     3.000000           0.370000
# 25%      18.150000           1.000000    74.000000           4.360000
# 50%      38.700000           4.000000    91.000000           5.800000
# 75%      55.000000          36.000000    96.000000           7.385000
# max      77.100000        2500.000000    99.000000          14.390000
#
#         diphtheria     hiv/aids            gdp    population  \
# count  1987.000000  1987.000000    1987.000000  1.987000e+03
# mean     80.454454     2.274937    5392.335709  1.358390e+07
# std      24.450153     6.005112   11480.810350  6.490113e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      75.500000     0.100000     384.553107  1.967480e+05
# 50%      91.000000     0.100000    1334.651896  1.396861e+06
# 75%      96.000000     1.400000    4441.530655  7.625918e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        thinness__1-19_years  thinness_5-9_years  \
# count           1987.000000         1987.000000
# mean               5.129995            5.199346
# std                4.750149            4.844382
# min                0.100000            0.100000
# 25%                1.600000            1.600000
# 50%                3.300000            3.400000
# 75%                7.600000            7.700000
# max               27.700000           28.600000
#
#        income_composition_of_resources    schooling
# count                      1987.000000  1987.000000
# mean                          0.603453    11.639054
# std                           0.206026     3.212964
# min                           0.000000     0.000000
# 25%                           0.473000     9.700000
# 50%                           0.648000    11.900000
# 75%                           0.745000    13.700000
# max                           0.936000    20.700000

# %%
all_col = ['life_expectancy','adult_mortality','infant_deaths',
         'alcohol','percentage_expenditure','hepatitis_b',
         'under-five_deaths','polio','total_expenditure',
         'diphtheria','gdp',
         'population','thinness__1-19_years','thinness_5-9_years',
         'income_composition_of_resources',
         'schooling']

plt.figure(figsize=(15,75))

for i in range(len(all_col)):
    plt.subplot(18,2,i+1)
    plt.hist(df[all_col[i]])
    plt.title(all_col[i])

plt.show()

# %%
df_skew = df.drop('year', axis = 1)

print(df_skew.skew())
# Out:
# life_expectancy                    -0.531505
# adult_mortality                     1.140995
# infant_deaths                       8.568802
# alcohol                             0.695528
# percentage_expenditure              4.762827
# hepatitis_b                        -1.311729
# measles                             8.764714
# bmi                                -0.095303
# under-five_deaths                   8.316159
# polio                              -1.881600
# total_expenditure                   0.238713
# diphtheria                         -1.903185
# hiv/aids                            4.544181
# gdp                                 4.298171
# population                         15.140323
# thinness__1-19_years                1.657464
# thinness_5-9_years                  1.715890
# income_composition_of_resources    -1.014837
# schooling                          -0.373064
# dtype: float64

# %%
print(df_skew.kurt())
# Out:
# life_expectancy                     -0.360747
# adult_mortality                      1.608679
# infant_deaths                       86.355275
# alcohol                             -0.513587
# percentage_expenditure              28.027316
# hepatitis_b                          0.444243
# measles                            100.421167
# bmi                                 -1.358437
# under-five_deaths                   81.576201
# polio                                2.817216
# total_expenditure                    0.025625
# diphtheria                           2.818479
# hiv/aids                            23.975688
# gdp                                 24.987776
# population                         266.685657
# thinness__1-19_years                 3.488271
# thinness_5-9_years                   3.829406
# income_composition_of_resources      1.152894
# schooling                            0.323281
# dtype: float64

# %%
df.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
needed1= df.drop(['country','year','status'], axis=1)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(needed1.corr(), annot=True)

# %%
df4=needed1.drop(['life_expectancy'], axis=1)

# %%
# !pip install factor_analyzer==0.2.3
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value,p_value=calculate_bartlett_sphericity(df4)
chi_square_value, p_value
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: factor_analyzer==0.2.3 in /usr/local/lib/python3.8/dist-packages (0.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from factor_analyzer==0.2.3) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from factor_analyzer==0.2.3) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from factor_analyzer==0.2.3) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->factor_analyzer==0.2.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->factor_analyzer==0.2.3) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->factor_analyzer==0.2.3) (1.15.0)
# (31177.507984855252, 0.0)

# %%
from factor_analyzer import FactorAnalyzer
fa = FactorAnalyzer()
fa.analyze(df4,16, rotation=None)

ev, v = fa.get_eigenvalues()
ev
# Out:
#     Original_Eigenvalues
# 0               5.718278
# 1               2.708570
# 2               1.812644
# 3               1.442644
# 4               1.115397
# 5               0.858556
# 6               0.781238
# 7               0.679065
# 8               0.534485
# 9               0.505775
# 10              0.477488
# 11              0.399086
# 12              0.380191
# 13              0.295624
# 14              0.181086
# 15              0.071941
# 16              0.035301
# 17              0.002630

# %%
fa = FactorAnalyzer()
fa.analyze(df4, 5, rotation="varimax")
fa.loadings
# Out:
#                                   Factor1   Factor2   Factor3   Factor4  \
# adult_mortality                 -0.238764 -0.033351 -0.139183 -0.144202
# infant_deaths                   -0.170341  0.972101 -0.102178 -0.029168
# alcohol                          0.521207  0.040903  0.203275  0.374983
# percentage_expenditure           0.199217 -0.040137  0.022921  0.923566
# hepatitis_b                      0.088095 -0.160559  0.591651 -0.072090
# measles                         -0.078664  0.490944 -0.115775 -0.041070
# bmi                              0.609077 -0.103070  0.202789  0.141477
# under-five_deaths               -0.171083  0.965234 -0.125367 -0.029761
# polio                            0.147752 -0.061038  0.720672  0.099946
# total_expenditure                0.253200 -0.097670  0.140301  0.163684
# diphtheria                       0.143630 -0.061831  0.829935  0.092106
# hiv/aids                        -0.076471 -0.011326 -0.073335 -0.015080
# gdp                              0.220699 -0.040210  0.049541  0.949038
# population                      -0.070542  0.560826  0.016529  0.012988
# thinness__1-19_years            -0.809841  0.371463 -0.022156 -0.053046
# thinness_5-9_years              -0.800000  0.378239 -0.020114 -0.050938
# income_composition_of_resources  0.534681  0.025894  0.418143  0.332152
# schooling                        0.581963 -0.010243  0.455454  0.348951
#
#                                   Factor5
# adult_mortality                  0.678644
# infant_deaths                   -0.000120
# alcohol                          0.035208
# percentage_expenditure          -0.095866
# hepatitis_b                     -0.051088
# measles                          0.000168
# bmi                             -0.254227
# under-five_deaths                0.016963
# polio                           -0.087321
# total_expenditure                0.046940
# diphtheria                      -0.083249
# hiv/aids                         0.743896
# gdp                             -0.105580
# population                      -0.039773
# thinness__1-19_years             0.155069
# thinness_5-9_years               0.161731
# income_composition_of_resources -0.240021
# schooling                       -0.196687

# %%
fa.get_factor_variance()
# Out:
#                  Factor1   Factor2   Factor3   Factor4   Factor5
# SS Loadings     2.898070  2.773663  2.111081  2.226851  1.267885
# Proportion Var  0.161004  0.154092  0.117282  0.123714  0.070438
# Cumulative Var  0.161004  0.315096  0.432379  0.556093  0.626531

# %%
df.describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count  1987.000000      1987.000000      1987.000000    1987.000000
# mean   2006.984902        67.981782       175.187217      36.623553
# std       4.323147         9.706401       131.616942     138.784913
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2003.000000        61.700000        75.000000       1.000000
# 50%    2007.000000        69.900000       153.000000       4.000000
# 75%    2011.000000        74.700000       243.000000      25.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            alcohol  percentage_expenditure  hepatitis_b        measles  \
# count  1987.000000             1987.000000   1987.00000    1987.000000
# mean      4.455644              685.492318     73.86160    2729.561651
# std       3.976733             1761.669050     29.02807   12102.389143
# min       0.010000                0.000000      2.00000       0.000000
# 25%       0.830000               29.469887     64.00000       0.000000
# 50%       3.770000              104.314473     86.00000      20.000000
# 75%       7.190000              470.870122     95.00000     499.500000
# max      17.870000            18961.348600     99.00000  212183.000000
#
#                bmi  under-five_deaths        polio  total_expenditure  \
# count  1987.000000        1987.000000  1987.000000        1987.000000
# mean     36.428636          50.932562    80.371917           5.902728
# std      19.736138         188.933117    24.363376           2.287467
# min       1.400000           0.000000     3.000000           0.370000
# 25%      18.150000           1.000000    74.000000           4.360000
# 50%      38.700000           4.000000    91.000000           5.800000
# 75%      55.000000          36.000000    96.000000           7.385000
# max      77.100000        2500.000000    99.000000          14.390000
#
#         diphtheria     hiv/aids            gdp    population  \
# count  1987.000000  1987.000000    1987.000000  1.987000e+03
# mean     80.454454     2.274937    5392.335709  1.358390e+07
# std      24.450153     6.005112   11480.810350  6.490113e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      75.500000     0.100000     384.553107  1.967480e+05
# 50%      91.000000     0.100000    1334.651896  1.396861e+06
# 75%      96.000000     1.400000    4441.530655  7.625918e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        thinness__1-19_years  thinness_5-9_years  \
# count           1987.000000         1987.000000
# mean               5.129995            5.199346
# std                4.750149            4.844382
# min                0.100000            0.100000
# 25%                1.600000            1.600000
# 50%                3.300000            3.400000
# 75%                7.600000            7.700000
# max               27.700000           28.600000
#
#        income_composition_of_resources    schooling
# count                      1987.000000  1987.000000
# mean                          0.603453    11.639054
# std                           0.206026     3.212964
# min                           0.000000     0.000000
# 25%                           0.473000     9.700000
# 50%                           0.648000    11.900000
# 75%                           0.745000    13.700000
# max                           0.936000    20.700000

# %%
df1=df[['country','life_expectancy', 'status', 'year']]
df1.head()
# Out:
#        country  life_expectancy      status  year
# 0  Afghanistan             65.0  Developing  2015
# 1  Afghanistan             59.9  Developing  2014
# 2  Afghanistan             59.9  Developing  2013
# 3  Afghanistan             59.5  Developing  2012
# 4  Afghanistan             59.2  Developing  2011

# %%
df1['status'] = df1.status.map({'Developing': 0, 'Developed': 1})
print(df1.head())
df1['status']= df1['status'].astype(int)
print(df1)
# Out:
#        country  life_expectancy  status  year
# 0  Afghanistan             65.0       0  2015
# 1  Afghanistan             59.9       0  2014
# 2  Afghanistan             59.9       0  2013
# 3  Afghanistan             59.5       0  2012
# 4  Afghanistan             59.2       0  2011
#           country  life_expectancy  status  year
# 0     Afghanistan             65.0       0  2015
# 1     Afghanistan             59.9       0  2014
# 2     Afghanistan             59.9       0  2013
# 3     Afghanistan             59.5       0  2012
# 4     Afghanistan             59.2       0  2011
# ...           ...              ...     ...   ...
# 2933     Zimbabwe             44.3       0  2004
# 2934     Zimbabwe             44.5       0  2003
# 2935     Zimbabwe             44.8       0  2002
# 2936     Zimbabwe             45.3       0  2001
# 2937     Zimbabwe             46.0       0  2000
#
# [1987 rows x 4 columns]

# %%
df5=df1.groupby(['country', 'status'])['life_expectancy'].mean()
df5
# Out:
# country      status
# Afghanistan  0         58.193750
# Albania      0         75.156250
# Algeria      0         73.486667
# Angola       0         48.793333
# Argentina    0         75.080000
#                          ...
# Uruguay      0         76.013333
# Uzbekistan   0         67.940000
# Vanuatu      0         71.346667
# Zambia       0         53.380000
# Zimbabwe     0         49.386667
# Name: life_expectancy, Length: 133, dtype: float64

# %%
df5.to_csv("hypothesis.csv")
df5 = pd.read_csv("hypothesis.csv")
df5.head()
# Out:
#        country  status  life_expectancy
# 0  Afghanistan       0        58.193750
# 1      Albania       0        75.156250
# 2      Algeria       0        73.486667
# 3       Angola       0        48.793333
# 4    Argentina       0        75.080000

# %%
df5['status'].value_counts()
# Out:
# 0    114
# 1     19
# Name: status, dtype: int64

# %%
developing = df5.loc[df5.status == 0]
developing.head()
# Out:
#        country  status  life_expectancy
# 0  Afghanistan       0        58.193750
# 1      Albania       0        75.156250
# 2      Algeria       0        73.486667
# 3       Angola       0        48.793333
# 4    Argentina       0        75.080000

# %%
developed = df5.loc[df5.status == 1]
developed.head()
# Out:
#       country  status  life_expectancy
# 6   Australia       1        81.746667
# 7     Austria       1        81.480000
# 11    Belgium       1        80.653333
# 18   Bulgaria       1        72.740000
# 32    Croatia       1        75.993333

# %%
from scipy.stats import normaltest

stat1, p1 = normaltest(developed['life_expectancy'])



print(stat1, p1)
# Out:
# 3.9356541782377645 0.13976021299963684

# %%
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
qqplot(developing['life_expectancy'], line='s')
plt.show()

# %%
mean_developing = developing['life_expectancy'].mean()
mean_developed = developed['life_expectancy'].mean()

print(f"The mean life expectancy of developing countries: {mean_developing}")
print(f"The mean life expectancy of developed countries: {mean_developed}")

s1 = developing['life_expectancy'].std()
s2 = developed['life_expectancy'].std()


n1 = developing['life_expectancy'].count()
n2 = developed['life_expectancy'].count()
print(f"S1 is: {s1} while s2 is: {s2}")
print("..............")
import math


sp = math.sqrt(((n1-1)*s1**2+(n2-1)*s2**2)/(n1+n2-2)) 

print(f"The pooled estimate of the commom stdev is: {round(sp,3)}, which is a value between {round(s1,3)} and {round(s2,3)}")
# Out:
# The mean life expectancy of developing countries: 66.18138157894737
# The mean life expectancy of developed countries: 78.83157894736843
# S1 is: 8.802853491784571 while s2 is: 3.4634257230077026
# ..............
# The pooled estimate of the commom stdev is: 8.276, which is a value between 8.803 and 3.463

# %%
z = (mean_developing-mean_developed)/(sp*math.sqrt((1/n1)+(1/n2)))
z
# Out:
# -6.168565484073584

# %%
from scipy import stats
from statsmodels.stats import weightstats as stests

# computing the z_test and p-value
ztest ,pval1 = stests.ztest(developing['life_expectancy'], developed['life_expectancy'], value=0,alternative='two-sided')
print(ztest, pval1)
if pval1 < 0.05:
    print("reject null hypothesis and accept the alternate hypothesis")
else:
    print("accept null hypothesis")
# Out:
# -6.168565484073583 6.891231036467113e-10
# reject null hypothesis and accept the alternate hypothesis

# %%
diff = mean_developed-mean_developing
diff
# Out:
# 12.650197368421061

# %%
df6=needed1.drop(labels=['percentage_expenditure',
       'diphtheria',
       'thinness_5-9_years', 'income_composition_of_resources'], axis=1)
df6
# Out:
#       life_expectancy  adult_mortality  infant_deaths  alcohol  hepatitis_b  \
# 0                65.0            263.0             62     0.01         65.0
# 1                59.9            271.0             64     0.01         62.0
# 2                59.9            268.0             66     0.01         64.0
# 3                59.5            272.0             69     0.01         67.0
# 4                59.2            275.0             71     0.01         68.0
# ...               ...              ...            ...      ...          ...
# 2933             44.3            723.0             27     4.36         68.0
# 2934             44.5            715.0             26     4.06          7.0
# 2935             44.8             73.0             25     4.43         73.0
# 2936             45.3            686.0             25     1.72         76.0
# 2937             46.0            665.0             24     1.68         79.0
#
#       measles   bmi  under-five_deaths  polio  total_expenditure  hiv/aids  \
# 0        1154  19.1                 83    6.0               8.16       0.1
# 1         492  18.6                 86   58.0               8.18       0.1
# 2         430  18.1                 89   62.0               8.13       0.1
# 3        2787  17.6                 93   67.0               8.52       0.1
# 4        3013  17.2                 97   68.0               7.87       0.1
# ...       ...   ...                ...    ...                ...       ...
# 2933       31  27.1                 42   67.0               7.13      33.6
# 2934      998  26.7                 41    7.0               6.52      36.7
# 2935      304  26.3                 40   73.0               6.53      39.8
# 2936      529  25.9                 39   76.0               6.16      42.1
# 2937     1483  25.5                 39   78.0               7.10      43.5
#
#              gdp  population  thinness__1-19_years  schooling
# 0     584.259210  33736494.0                  17.2       10.1
# 1     612.696514    327582.0                  17.5       10.0
# 2     631.744976  31731688.0                  17.7        9.9
# 3     669.959000   3696958.0                  17.9        9.8
# 4      63.537231   2978599.0                  18.2        9.5
# ...          ...         ...                   ...        ...
# 2933  454.366654  12777511.0                   9.4        9.2
# 2934  453.351155  12633897.0                   9.8        9.5
# 2935   57.348340    125525.0                   1.2       10.0
# 2936  548.587312  12366165.0                   1.6        9.8
# 2937  547.358878  12222251.0                  11.0        9.8
#
# [1987 rows x 15 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
shape=df6.shape
print("Dataset contains {} rows and {} columns".format(shape[0],shape[1]))
# Out:
# Dataset contains 1987 rows and 15 columns

# %%
df6.columns
# Out:
# Index(['life_expectancy', 'adult_mortality', 'infant_deaths', 'alcohol',
#        'hepatitis_b', 'measles', 'bmi', 'under-five_deaths', 'polio',
#        'total_expenditure', 'hiv/aids', 'gdp', 'population',
#        'thinness__1-19_years', 'schooling'],
#       dtype='object')

# %%
x=df6.iloc[:,1:12]
y=df6.iloc[:,0]

# %%
x
# Out:
#       adult_mortality  infant_deaths  alcohol  hepatitis_b  measles   bmi  \
# 0               263.0             62     0.01         65.0     1154  19.1
# 1               271.0             64     0.01         62.0      492  18.6
# 2               268.0             66     0.01         64.0      430  18.1
# 3               272.0             69     0.01         67.0     2787  17.6
# 4               275.0             71     0.01         68.0     3013  17.2
# ...               ...            ...      ...          ...      ...   ...
# 2933            723.0             27     4.36         68.0       31  27.1
# 2934            715.0             26     4.06          7.0      998  26.7
# 2935             73.0             25     4.43         73.0      304  26.3
# 2936            686.0             25     1.72         76.0      529  25.9
# 2937            665.0             24     1.68         79.0     1483  25.5
#
#       under-five_deaths  polio  total_expenditure  hiv/aids         gdp
# 0                    83    6.0               8.16       0.1  584.259210
# 1                    86   58.0               8.18       0.1  612.696514
# 2                    89   62.0               8.13       0.1  631.744976
# 3                    93   67.0               8.52       0.1  669.959000
# 4                    97   68.0               7.87       0.1   63.537231
# ...                 ...    ...                ...       ...         ...
# 2933                 42   67.0               7.13      33.6  454.366654
# 2934                 41    7.0               6.52      36.7  453.351155
# 2935                 40   73.0               6.53      39.8   57.348340
# 2936                 39   76.0               6.16      42.1  548.587312
# 2937                 39   78.0               7.10      43.5  547.358878
#
# [1987 rows x 11 columns]

# %%
y
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: life_expectancy, Length: 1987, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print("X_train:",x_train.shape)
print("X_test:",x_test.shape)
print("Y_train:",y_train.shape)
print("Y_test:",y_test.shape)
# Out:
# X_train: (1589, 11)
# X_test: (398, 11)
# Y_train: (1589,)
# Y_test: (398,)

# %%
linreg=LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(x_test)
y_pred
# Out:
# array([65.16, 74.42, 66.56, 84.51, 79.15, 75.15, 80.63, 73.52, 74.03,
#        74.57, 73.37, 59.62, 72.44, 74.34, 71.66, 73.8 , 71.05, 73.09,
#        74.99, 65.48, 61.21, 59.71, 64.13, 62.9 , 63.69, 62.87, 70.5 ,
#        64.16, 72.36, 65.26, 69.7 , 63.05, 67.9 , 70.29, 72.6 , 63.76,
#        74.15, 74.47, 76.32, 74.36, 74.79, 72.62, 71.21, 76.12, 73.52,
#        71.32, 78.49, 73.64, 73.21, 71.05, 57.26, 76.18, 74.4 , 74.4 ,
#        80.54, 60.97, 68.1 , 64.97, 39.25, 68.65, 71.83, 59.76, 68.86,
#        66.31, 61.36, 65.26, 61.34, 66.72, 59.28, 58.62, 77.29, 74.67,
#        79.22, 55.61, 68.37, 69.29, 72.98, 72.52, 59.82, 74.34, 74.75,
#        70.56, 68.22, 67.51, 66.57, 76.41, 61.98, 61.79, 61.76, 72.19,
#        59.36, 67.46, 68.76, 73.12, 68.38, 68.11, 70.22, 72.5 , 69.09,
#        78.  , 79.84, 64.14, 55.89, 72.09, 68.7 , 76.33, 76.99, 63.95,
#        72.34, 61.65, 73.  , 60.94, 42.35, 74.52, 62.31, 75.17, 64.7 ,
#        60.61, 72.81, 61.59, 70.68, 73.78, 61.03, 50.86, 53.34, 71.34,
#        81.47, 65.54, 64.22, 65.59, 61.95, 74.28, 75.6 , 61.99, 69.48,
#        60.2 , 58.62, 57.3 , 70.65, 64.58, 68.9 , 73.71, 71.19, 74.54,
#        66.28, 74.83, 61.25, 74.18, 76.65, 64.22, 57.44, 56.27, 74.12,
#        37.45, 70.34, 73.31, 72.25, 70.74, 67.93, 60.78, 65.41, 67.58,
#        70.73, 52.3 , 74.84, 74.06, 81.23, 59.15, 76.23, 60.51, 71.56,
#        76.53, 80.52, 66.56, 42.24, 76.92, 66.92, 62.58, 52.35, 74.79,
#        75.51, 68.91, 66.25, 66.18, 69.55, 80.34, 69.66, 60.88, 77.88,
#        62.59, 67.38, 70.83, 72.52, 72.28, 62.4 , 75.99, 61.36, 71.53,
#        67.08, 80.86, 74.04, 62.25, 63.99, 43.5 , 53.18, 64.39, 57.71,
#        72.32, 77.03, 66.5 , 73.33, 64.3 , 55.97, 74.09, 63.31, 60.97,
#        67.18, 55.3 , 67.22, 71.22, 77.89, 60.16, 68.24, 66.2 , 79.99,
#        61.82, 65.6 , 71.33, 70.69, 73.18, 71.48, 70.25, 74.37, 68.91,
#        58.29, 52.95, 58.68, 73.39, 60.26, 68.8 , 79.78, 46.6 , 59.72,
#        68.67, 65.82, 61.48, 58.82, 75.17, 70.37, 65.53, 75.18, 69.19,
#        68.01, 59.8 , 73.71, 55.34, 64.42, 74.03, 60.49, 58.78, 75.35,
#        78.07, 74.8 , 51.01, 66.78, 68.03, 72.72, 64.85, 72.77, 73.66,
#        67.99, 68.84, 62.39, 60.51, 70.57, 63.51, 77.72, 74.91, 70.12,
#        62.43, 69.64, 76.31, 65.87, 73.21, 66.45, 65.13, 67.24, 56.83,
#        66.51, 69.72, 67.  , 59.5 , 64.58, 75.47, 68.81, 81.67, 59.08,
#        72.87, 74.94, 55.43, 62.98, 68.4 , 67.06, 63.84, 56.83, 64.55,
#        75.82, 63.74, 64.83, 77.61, 75.1 , 41.88, 59.05, 73.39, 58.12,
#        68.99, 70.46, 67.08, 47.93, 74.87, 61.86, 53.91, 56.63, 74.3 ,
#        74.37, 63.52, 63.3 , 87.05, 63.86, 67.24, 70.56, 69.2 , 76.2 ,
#        70.86, 68.61, 62.18, 65.81, 64.36, 69.34, 71.63, 71.44, 58.92,
#        60.69, 75.37, 74.53, 76.46, 86.57, 59.17, 79.83, 69.06, 66.5 ,
#        66.49, 57.77, 68.81, 72.8 , 62.05, 71.05, 53.46, 81.93, 72.09,
#        58.15, 72.69, 57.91, 66.26, 77.44, 72.74, 76.94, 68.14, 58.85,
#        69.51, 66.96, 76.81, 65.07, 61.36, 67.16, 73.32, 72.33, 64.34,
#        84.58, 61.03, 69.11, 61.37, 73.  , 49.23, 72.26, 66.89, 67.97,
#        58.4 , 59.49, 63.44, 51.4 , 65.95, 71.32, 62.7 , 58.28, 71.45,
#        69.69, 80.57])

# %%
Accuracy=r2_score(y_test,y_pred)*100
print(" Accuracy of the model is %.2f" %Accuracy)
# Out:
#  Accuracy of the model is 73.38

# %%
plt.scatter(y_test,y_pred);
plt.xlabel('Actual');
plt.ylabel('Predicted');

# %%
sns.regplot(x=y_test,y=y_pred,ci=None,color ='red');

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})

# %%
pred_df
# Out:
#       Actual Value  Predicted Value  Difference
# 1799          65.8        65.162475    0.637525
# 1684          76.6        74.421388    2.178612
# 2563          65.5        66.560710   -1.060710
# 129           81.4        84.508900   -3.108900
# 942           79.3        79.150803    0.149197
# ...            ...              ...         ...
# 494           51.5        62.696809  -11.196809
# 2625          55.9        58.279364   -2.379364
# 1392          64.3        71.446768   -7.146768
# 998           85.0        69.691903   15.308097
# 2065          77.7        80.571136   -2.871136
#
# [398 rows x 3 columns]

# %%
import pandas
from sklearn import linear_model

# %%
print("Intercept: ", linreg.intercept_)
print("Coefficients:")
list(zip(x, linreg.coef_))
# Out:
# Intercept:  60.98820835889948
# Coefficients:
# [('adult_mortality', -0.020282703884139486),
#  ('infant_deaths', 0.14090627274100934),
#  ('alcohol', 0.3127509226550721),
#  ('hepatitis_b', 0.01146115379594738),
#  ('measles', -8.718630928826986e-06),
#  ('bmi', 0.12830610008935256),
#  ('under-five_deaths', -0.10521958883895374),
#  ('polio', 0.043676734980143336),
#  ('total_expenditure', 0.1126352822946912),
#  ('hiv/aids', -0.47237519893863217),
#  ('gdp', 0.00013760172075466537)]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=101)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
y_pred = np.array(y_pred)
y_test = np.array(y_test)

print(np.concatenate((y_pred.reshape(len(y_test),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[73.06 69.8 ]
#  [73.7  79.  ]
#  [76.54 78.2 ]
#  [56.37 58.2 ]
#  [66.84 67.  ]
#  [73.28 73.  ]
#  [72.91 73.1 ]
#  [52.45 53.2 ]
#  [56.87 57.3 ]
#  [84.29 86.  ]
#  [48.45 47.7 ]
#  [60.65 59.7 ]
#  [75.76 73.4 ]
#  [72.88 72.3 ]
#  [81.28 81.2 ]
#  [53.01 53.2 ]
#  [71.14 69.4 ]
#  [58.05 58.1 ]
#  [51.46 54.1 ]
#  [79.52 78.4 ]
#  [72.28 72.7 ]
#  [64.48 65.4 ]
#  [74.35 74.4 ]
#  [72.44 72.  ]
#  [54.8  54.2 ]
#  [69.34 68.4 ]
#  [71.98 71.8 ]
#  [81.69 79.5 ]
#  [67.84 68.1 ]
#  [71.21 71.1 ]
#  [53.97 53.  ]
#  [74.32 72.7 ]
#  [75.54 75.8 ]
#  [73.93 73.7 ]
#  [72.07 71.6 ]
#  [79.22 78.4 ]
#  [65.1  62.9 ]
#  [75.79 76.8 ]
#  [74.28 71.2 ]
#  [77.34 78.3 ]
#  [65.13 64.6 ]
#  [53.34 52.5 ]
#  [68.87 69.3 ]
#  [68.57 68.  ]
#  [73.8  74.5 ]
#  [54.3  51.5 ]
#  [73.92 77.  ]
#  [79.31 78.2 ]
#  [64.26 63.2 ]
#  [45.28 43.8 ]
#  [55.22 54.3 ]
#  [75.09 75.6 ]
#  [72.5  72.1 ]
#  [57.53 57.3 ]
#  [74.52 72.5 ]
#  [79.29 78.7 ]
#  [67.81 67.1 ]
#  [71.8  69.7 ]
#  [52.11 54.  ]
#  [75.57 75.4 ]
#  [77.54 77.5 ]
#  [64.92 65.3 ]
#  [71.01 73.  ]
#  [73.91 72.9 ]
#  [72.92 72.  ]
#  [47.15 42.3 ]
#  [77.02 76.3 ]
#  [64.66 64.7 ]
#  [79.1  79.1 ]
#  [69.38 68.4 ]
#  [59.43 58.7 ]
#  [47.77 46.4 ]
#  [65.95 64.  ]
#  [58.95 59.1 ]
#  [72.67 72.4 ]
#  [52.9  51.  ]
#  [56.16 60.  ]
#  [67.55 67.9 ]
#  [82.47 79.9 ]
#  [70.72 73.  ]
#  [69.42 67.6 ]
#  [59.75 59.1 ]
#  [70.08 69.3 ]
#  [76.51 76.3 ]
#  [65.24 64.8 ]
#  [76.43 77.  ]
#  [73.22 77.  ]
#  [61.   65.  ]
#  [59.42 59.2 ]
#  [70.2  69.6 ]
#  [74.99 75.  ]
#  [52.08 53.2 ]
#  [60.92 61.5 ]
#  [65.46 68.3 ]
#  [48.61 47.4 ]
#  [59.9  59.4 ]
#  [73.04 72.7 ]
#  [73.62 73.6 ]
#  [51.19 52.6 ]
#  [58.15 57.7 ]
#  [72.97 73.  ]
#  [74.99 75.9 ]
#  [63.62 63.3 ]
#  [72.42 70.  ]
#  [72.3  76.  ]
#  [52.55 56.  ]
#  [72.92 72.7 ]
#  [64.98 65.1 ]
#  [80.36 78.5 ]
#  [71.26 72.6 ]
#  [69.46 69.7 ]
#  [64.33 65.9 ]
#  [84.2  84.  ]
#  [74.56 75.  ]
#  [54.5  53.6 ]
#  [67.06 67.7 ]
#  [75.87 77.3 ]
#  [68.32 69.4 ]
#  [74.16 74.7 ]
#  [67.95 68.2 ]
#  [59.97 59.5 ]
#  [66.96 69.1 ]
#  [58.6  61.8 ]
#  [72.28 71.8 ]
#  [55.68 57.4 ]
#  [47.7  47.1 ]
#  [71.81 71.6 ]
#  [72.73 72.1 ]
#  [51.89 53.  ]
#  [74.89 74.9 ]
#  [76.73 75.9 ]
#  [67.19 67.2 ]
#  [63.   62.1 ]
#  [73.37 72.6 ]
#  [80.99 88.  ]
#  [62.4  66.  ]
#  [76.83 77.  ]
#  [52.39 55.  ]
#  [51.26 52.2 ]
#  [50.83 49.4 ]
#  [83.58 81.  ]
#  [73.73 73.8 ]
#  [67.79 67.1 ]
#  [58.01 56.7 ]
#  [82.26 81.2 ]
#  [78.52 78.7 ]
#  [72.58 72.4 ]
#  [74.71 75.5 ]
#  [46.26 45.6 ]
#  [70.44 68.6 ]
#  [66.38 66.2 ]
#  [61.73 59.6 ]
#  [53.1  53.3 ]
#  [74.81 75.  ]
#  [53.71 56.7 ]
#  [55.19 53.1 ]
#  [81.85 81.  ]
#  [66.24 65.8 ]
#  [74.78 76.  ]
#  [68.51 66.7 ]
#  [63.05 62.7 ]
#  [81.05 79.8 ]
#  [54.03 52.8 ]
#  [73.47 71.1 ]
#  [60.18 62.9 ]
#  [67.27 68.9 ]
#  [76.73 76.9 ]
#  [56.78 55.6 ]
#  [78.73 77.8 ]
#  [50.06 49.2 ]
#  [75.4  76.2 ]
#  [67.63 69.4 ]
#  [75.45 75.8 ]
#  [80.56 85.  ]
#  [58.64 58.  ]
#  [45.2  45.5 ]
#  [56.24 59.1 ]
#  [64.38 61.  ]
#  [72.01 74.  ]
#  [76.18 76.5 ]
#  [74.48 75.5 ]
#  [73.3  76.  ]
#  [47.43 44.3 ]
#  [73.65 74.5 ]
#  [69.03 71.1 ]
#  [82.41 81.1 ]
#  [75.53 75.7 ]
#  [69.97 69.4 ]
#  [72.94 72.4 ]
#  [46.93 47.8 ]
#  [71.68 71.  ]
#  [69.95 69.2 ]
#  [72.79 73.  ]
#  [73.12 72.5 ]
#  [56.15 56.1 ]
#  [75.14 75.  ]
#  [57.09 68.  ]
#  [74.34 73.5 ]
#  [72.95 73.  ]
#  [72.71 72.8 ]
#  [45.8  45.3 ]
#  [69.98 71.  ]
#  [78.69 79.5 ]
#  [61.98 59.2 ]
#  [67.53 65.8 ]
#  [71.38 71.4 ]
#  [51.6  48.3 ]
#  [73.18 75.  ]
#  [79.82 79.1 ]
#  [70.65 72.  ]
#  [72.01 72.7 ]
#  [50.29 41.5 ]
#  [67.34 67.3 ]
#  [75.56 75.  ]
#  [69.89 71.2 ]
#  [62.9  69.  ]
#  [72.63 72.6 ]
#  [67.69 67.8 ]
#  [67.14 65.9 ]
#  [66.95 68.7 ]
#  [51.13 45.7 ]
#  [48.39 46.6 ]
#  [55.52 60.  ]
#  [54.34 58.5 ]
#  [53.19 52.  ]
#  [74.52 75.6 ]
#  [74.49 74.8 ]
#  [67.44 65.4 ]
#  [56.03 56.4 ]
#  [58.77 59.2 ]
#  [63.24 64.7 ]
#  [66.99 66.8 ]
#  [74.34 74.4 ]
#  [65.57 59.  ]
#  [59.2  57.7 ]
#  [69.33 68.5 ]
#  [68.91 69.3 ]
#  [66.58 67.  ]
#  [67.79 67.5 ]
#  [75.68 75.7 ]
#  [65.2  66.1 ]
#  [51.14 53.  ]
#  [79.36 78.3 ]
#  [81.83 81.8 ]
#  [64.19 64.1 ]
#  [73.75 71.4 ]
#  [68.31 68.1 ]
#  [72.97 72.8 ]
#  [75.94 76.1 ]
#  [74.25 71.4 ]
#  [48.89 48.1 ]
#  [67.89 74.  ]
#  [72.45 78.  ]
#  [44.7  43.5 ]
#  [74.56 76.6 ]
#  [80.66 89.  ]
#  [54.46 61.5 ]
#  [60.27 65.  ]
#  [73.65 72.8 ]
#  [62.65 63.  ]
#  [82.84 86.  ]
#  [81.92 81.7 ]
#  [73.49 73.9 ]
#  [70.57 71.8 ]
#  [53.47 53.6 ]
#  [80.45 79.5 ]
#  [65.63 65.4 ]
#  [63.07 62.9 ]
#  [62.77 63.1 ]
#  [56.17 55.5 ]
#  [52.65 57.  ]
#  [73.25 72.5 ]
#  [73.29 75.4 ]
#  [64.29 65.1 ]
#  [72.74 73.  ]
#  [52.34 52.1 ]
#  [75.77 75.9 ]
#  [68.08 68.  ]
#  [61.69 63.  ]
#  [66.05 66.  ]
#  [70.88 71.3 ]
#  [63.43 61.8 ]
#  [71.5  76.  ]
#  [74.97 74.9 ]
#  [63.69 63.8 ]
#  [67.93 67.9 ]
#  [72.83 72.2 ]
#  [81.47 82.  ]
#  [73.63 73.1 ]
#  [55.93 54.3 ]
#  [72.43 71.9 ]
#  [69.49 66.3 ]
#  [72.77 72.7 ]
#  [72.82 72.4 ]
#  [76.94 76.9 ]
#  [61.69 66.  ]
#  [71.02 71.4 ]
#  [73.27 73.  ]
#  [66.62 66.2 ]
#  [70.87 71.7 ]
#  [78.77 78.3 ]
#  [75.87 75.3 ]
#  [74.27 74.4 ]
#  [55.07 55.  ]
#  [53.59 51.  ]
#  [56.79 57.8 ]
#  [54.21 50.  ]
#  [73.7  73.7 ]
#  [69.91 69.6 ]
#  [69.45 69.  ]
#  [49.   51.  ]
#  [73.67 74.4 ]
#  [83.3  84.  ]
#  [81.97 79.8 ]
#  [73.78 74.5 ]
#  [72.87 72.6 ]
#  [69.78 67.8 ]
#  [63.06 61.4 ]
#  [72.5  71.4 ]
#  [67.93 67.9 ]
#  [53.28 45.3 ]
#  [71.85 72.7 ]
#  [74.3  75.3 ]
#  [66.64 66.6 ]
#  [79.08 78.9 ]
#  [81.55 79.8 ]
#  [54.31 53.5 ]
#  [73.97 73.5 ]
#  [63.97 63.3 ]
#  [75.03 74.7 ]
#  [71.39 70.  ]
#  [46.51 46.  ]
#  [68.06 67.8 ]
#  [66.8  67.4 ]
#  [54.42 54.8 ]
#  [66.56 61.4 ]
#  [66.96 67.4 ]
#  [65.97 66.9 ]
#  [72.31 72.5 ]
#  [75.92 76.2 ]
#  [53.36 54.9 ]
#  [71.09 72.9 ]
#  [71.71 71.  ]
#  [65.51 65.9 ]
#  [73.68 73.8 ]
#  [63.01 64.  ]
#  [77.82 71.6 ]
#  [71.63 73.2 ]
#  [72.97 73.6 ]
#  [73.   74.1 ]
#  [76.36 73.8 ]
#  [51.57 52.4 ]
#  [55.72 57.3 ]
#  [71.83 72.8 ]
#  [63.06 63.3 ]
#  [61.64 61.6 ]
#  [54.11 51.9 ]
#  [73.24 73.9 ]
#  [67.   65.9 ]
#  [55.32 67.  ]
#  [78.32 78.8 ]
#  [72.51 73.1 ]
#  [72.46 74.1 ]
#  [70.25 68.5 ]
#  [74.79 74.5 ]
#  [81.61 83.  ]
#  [74.52 71.2 ]
#  [65.67 65.3 ]
#  [72.59 72.6 ]
#  [64.77 65.  ]
#  [73.02 73.7 ]
#  [72.46 72.2 ]
#  [62.92 62.5 ]
#  [71.96 72.9 ]
#  [77.01 76.8 ]
#  [63.51 63.9 ]
#  [65.74 66.8 ]
#  [52.13 52.1 ]
#  [74.09 74.8 ]
#  [70.58 71.  ]
#  [66.08 65.5 ]
#  [64.45 65.  ]
#  [74.28 76.6 ]
#  [68.64 67.3 ]
#  [79.47 78.1 ]
#  [81.23 79.7 ]
#  [72.14 73.6 ]
#  [68.82 68.4 ]
#  [73.76 73.7 ]
#  [73.3  73.2 ]
#  [59.52 58.6 ]
#  [66.84 72.9 ]
#  [59.62 59.9 ]
#  [45.69 39.  ]
#  [65.8  66.3 ]
#  [55.49 57.2 ]
#  [83.47 81.6 ]
#  [79.11 79.3 ]]

# %%
accuracy_score =  regressor.score(X_test,y_test)
print(accuracy_score)
# Out:
# 0.9520061204483174

# %%
print('Random Forest Classifier Accuracy:',(accuracy_score)*100,'%')
# Out:
# Random Forest Classifier Accuracy: 95.20061204483174 %

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print(mean_squared_error(y_test,y_pred)**(0.5))
# Out:
# 2.0846776409877315

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(regressor,X_train,y_train,cv=10)
accuracies.mean()
# Out:
# 0.951632196468221

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})

# %%
pred_df
# Out:
#      Actual Value  Predicted Value  Difference
# 0            69.8           73.058      -3.258
# 1            79.0           73.703       5.297
# 2            78.2           76.540       1.660
# 3            58.2           56.369       1.831
# 4            67.0           66.843       0.157
# ..            ...              ...         ...
# 393          39.0           45.692      -6.692
# 394          66.3           65.803       0.497
# 395          57.2           55.486       1.714
# 396          81.6           83.466      -1.866
# 397          79.3           79.113       0.187
#
# [398 rows x 3 columns]

# %%
from datetime import datetime
import numpy as np             #for numerical computations like log,exp,sqrt etc
import pandas as pd            #for reading & storing data, pre-processing
import matplotlib.pylab as plt #for visualization
#for making sure matplotlib plots are generated in Jupyter notebook itself
# %matplotlib inline 
from pandas.plotting import lag_plot            
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 6

# %%
from statsmodels.tsa.stattools import adfuller

#perform augmented Dickey-Fuller test
adfuller(df['life_expectancy'])
# Out:
# (-8.48906239419417,
#  1.3286466893546597e-13,
#  15,
#  1971,
#  {'1%': -3.4336720887549483,
#   '5%': -2.863007508094813,
#   '10%': -2.567551240570721},
#  10951.861868512995)

# %%
! pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.8/dist-packages (2.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)

# %%
df7=pd.read_csv('/content/drive/MyDrive/Life Expectancy Data.csv' ,index_col='Year',parse_dates=True)
df7=df7.dropna()
print('Shape of data' ,df7.shape)
df7.head()
# Out:
# Shape of data (1649, 21)
#                 Country      Status  Life expectancy   Adult Mortality  \
# Year
# 2015-01-01  Afghanistan  Developing              65.0            263.0
# 2014-01-01  Afghanistan  Developing              59.9            271.0
# 2013-01-01  Afghanistan  Developing              59.9            268.0
# 2012-01-01  Afghanistan  Developing              59.5            272.0
# 2011-01-01  Afghanistan  Developing              59.2            275.0
#
#             infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Year
# 2015-01-01             62     0.01               71.279624         65.0
# 2014-01-01             64     0.01               73.523582         62.0
# 2013-01-01             66     0.01               73.219243         64.0
# 2012-01-01             69     0.01               78.184215         67.0
# 2011-01-01             71     0.01                7.097109         68.0
#
#             Measles    BMI   ...  Polio  Total expenditure  Diphtheria   \
# Year                         ...
# 2015-01-01      1154   19.1  ...    6.0               8.16         65.0
# 2014-01-01       492   18.6  ...   58.0               8.18         62.0
# 2013-01-01       430   18.1  ...   62.0               8.13         64.0
# 2012-01-01      2787   17.6  ...   67.0               8.52         67.0
# 2011-01-01      3013   17.2  ...   68.0               7.87         68.0
#
#              HIV/AIDS         GDP  Population   thinness  1-19 years  \
# Year
# 2015-01-01        0.1  584.259210  33736494.0                   17.2
# 2014-01-01        0.1  612.696514    327582.0                   17.5
# 2013-01-01        0.1  631.744976  31731688.0                   17.7
# 2012-01-01        0.1  669.959000   3696958.0                   17.9
# 2011-01-01        0.1   63.537231   2978599.0                   18.2
#
#              thinness 5-9 years  Income composition of resources  Schooling
# Year
# 2015-01-01                 17.3                            0.479       10.1
# 2014-01-01                 17.5                            0.476       10.0
# 2013-01-01                 17.7                            0.470        9.9
# 2012-01-01                 18.0                            0.463        9.8
# 2011-01-01                 18.2                            0.454        9.5
#
# [5 rows x 21 columns]

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

model = pm.auto_arima(y_train, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-202-5556c77075e3> in <module>
#       1 from statsmodels.tsa.arima_model import ARIMA
# ----> 2 import pmdarima as pm
#       3
#       4 model = pm.auto_arima(y_train, start_p=1, start_q=1,
#       5                       test='adf',       # use adftest to find optimal 'd'
#
# /usr/local/lib/python3.8/dist-packages/pmdarima/__init__.py in <module>
#      50
#      51     # Stuff we want at top-level
# ---> 52     from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53     from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54         tsdisplay
#
# /usr/local/lib/python3.8/dist-packages/pmdarima/arima/__init__.py in <module>
#       4
#       5 from .approx import *
# ----> 6 from .arima import *
#       7 from .auto import *
#       8 from .utils import *
#
# /usr/local/lib/python3.8/dist-packages/pmdarima/arima/arima.py in <module>
#      14 from scipy.stats import gaussian_kde, norm
#      15 from sklearn.utils.validation import check_array
# ---> 16 from statsmodels import api as sm
#      17
#      18 from . import _validation as val
#
# /usr/local/lib/python3.8/dist-packages/statsmodels/api.py in <module>
#      71
#      72 from . import datasets, distributions, iolib, regression, robust, tools
# ---> 73 from .__init__ import test
#      74 from .discrete.count_model import (
#      75     ZeroInflatedGeneralizedPoisson,
#
# /usr/local/lib/python3.8/dist-packages/statsmodels/__init__.py in <module>
# ----> 1 from statsmodels._version import __version__, __version_tuple__
#       2
#       3 debug_warnings = False
#       4
#       5 if debug_warnings:
#
# ImportError: cannot import name '__version__' from 'statsmodels._version' (/usr/local/lib/python3.8/dist-packages/statsmodels/_version.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
