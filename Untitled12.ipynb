# %% [markdown]
# <a href="https://colab.research.google.com/github/glennamaria/task1/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas.util.testing as tm
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   """

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/dataset"
df= pd.read_csv(path)
df
# Out:
#          Country  Year      Status  Life expectancy   Adult Mortality  \
# 0    Afghanistan  2015  Developing              65.0              263
# 1    Afghanistan  2014  Developing              59.9              271
# 2    Afghanistan  2013  Developing              59.9              268
# 3    Afghanistan  2012  Developing              59.5              272
# 4    Afghanistan  2011  Developing              59.2              275
# ..           ...   ...         ...               ...              ...
# 699        Yemen  2004  Developing              62.2              247
# 700        Yemen  2003  Developing              61.9              249
# 701        Yemen  2002  Developing              61.5               25
# 702        Yemen  2001  Developing              61.1              251
# 703        Yemen  2000  Developing              68.0              252
#
#      infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0               62     0.01               71.279624         65.0      1154
# 1               64     0.01               73.523582         62.0       492
# 2               66     0.01               73.219243         64.0       430
# 3               69     0.01               78.184215         67.0      2787
# 4               71     0.01                7.097109         68.0      3013
# ..             ...      ...                     ...          ...       ...
# 699             42     0.06                0.000000         43.0     12708
# 700             43     0.04                0.000000         38.0      8536
# 701             45     0.07                0.000000         31.0       890
# 702             46     0.08                0.000000         19.0       485
# 703             48     0.07                0.000000         14.0         0
#
#      ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0    ...      6               8.16           65        0.1  584.259210
# 1    ...     58               8.18           62        0.1  612.696514
# 2    ...     62               8.13           64        0.1  631.744976
# 3    ...     67               8.52           67        0.1  669.959000
# 4    ...     68               7.87           68        0.1   63.537231
# ..   ...    ...                ...          ...        ...         ...
# 699  ...     72               4.90           72        0.1         NaN
# 700  ...     61               5.00           61        0.1         NaN
# 701  ...     64               4.22           65        0.1         NaN
# 702  ...     73               4.34           73        0.1         NaN
# 703  ...     74               4.14           74        0.1         NaN
#
#      Population   thinness  1-19 years   thinness 5-9 years  \
# 0    33736494.0                   17.2                 17.3
# 1      327582.0                   17.5                 17.5
# 2    31731688.0                   17.7                 17.7
# 3     3696958.0                   17.9                 18.0
# 4     2978599.0                   18.2                 18.2
# ..          ...                    ...                  ...
# 699         NaN                   13.9                 13.9
# 700         NaN                   14.0                 13.9
# 701         NaN                   14.0                 14.0
# 702         NaN                   14.0                 14.0
# 703         NaN                   14.1                 14.1
#
#      Income composition of resources  Schooling
# 0                              0.479       10.1
# 1                              0.476       10.0
# 2                              0.470        9.9
# 3                              0.463        9.8
# 4                              0.454        9.5
# ..                               ...        ...
# 699                            0.464        8.4
# 700                            0.457        8.2
# 701                            0.450        8.0
# 702                            0.444        7.9
# 703                            0.436        7.7
#
# [704 rows x 22 columns]

# %%
df.shape
# Out:
# (704, 22)

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0              263
# 1  Afghanistan  2014  Developing              59.9              271
# 2  Afghanistan  2013  Developing              59.9              268
# 3  Afghanistan  2012  Developing              59.5              272
# 4  Afghanistan  2011  Developing              59.2              275
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0      6               8.16           65        0.1  584.259210  33736494.0
# 1     58               8.18           62        0.1  612.696514    327582.0
# 2     62               8.13           64        0.1  631.744976  31731688.0
# 3     67               8.52           67        0.1  669.959000   3696958.0
# 4     68               7.87           68        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#     Country  Year      Status  Life expectancy   Adult Mortality  \
# 699   Yemen  2004  Developing              62.2              247
# 700   Yemen  2003  Developing              61.9              249
# 701   Yemen  2002  Developing              61.5               25
# 702   Yemen  2001  Developing              61.1              251
# 703   Yemen  2000  Developing              68.0              252
#
#      infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 699             42     0.06                     0.0         43.0     12708
# 700             43     0.04                     0.0         38.0      8536
# 701             45     0.07                     0.0         31.0       890
# 702             46     0.08                     0.0         19.0       485
# 703             48     0.07                     0.0         14.0         0
#
#      ...  Polio  Total expenditure  Diphtheria    HIV/AIDS  GDP  Population  \
# 699  ...     72               4.90           72        0.1  NaN         NaN
# 700  ...     61               5.00           61        0.1  NaN         NaN
# 701  ...     64               4.22           65        0.1  NaN         NaN
# 702  ...     73               4.34           73        0.1  NaN         NaN
# 703  ...     74               4.14           74        0.1  NaN         NaN
#
#       thinness  1-19 years   thinness 5-9 years  \
# 699                   13.9                 13.9
# 700                   14.0                 13.9
# 701                   14.0                 14.0
# 702                   14.0                 14.0
# 703                   14.1                 14.1
#
#      Income composition of resources  Schooling
# 699                            0.464        8.4
# 700                            0.457        8.2
# 701                            0.450        8.0
# 702                            0.444        7.9
# 703                            0.436        7.7
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                      int64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                                int64
# Total expenditure                  float64
# Diphtheria                           int64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print(df.columns)
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# country                              0
# year                                 0
# status                               0
# life_expectancy                      0
# adult_mortality                      0
# infant_deaths                        0
# alcohol                             42
# percentage_expenditure               0
# hepatitis_b                         55
# measles                              0
# bmi                                  0
# under-five_deaths                    0
# polio                                0
# total_expenditure                   46
# diphtheria                           0
# hiv/aids                             0
# gdp                                 92
# population                         208
# thinness__1-19_years                 0
# thinness_5-9_years                   0
# income_composition_of_resources      0
# schooling                            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          704 non-null    object
#  1   year                             704 non-null    int64
#  2   status                           704 non-null    object
#  3   life_expectancy                  704 non-null    float64
#  4   adult_mortality                  704 non-null    int64
#  5   infant_deaths                    704 non-null    int64
#  6   alcohol                          662 non-null    float64
#  7   percentage_expenditure           704 non-null    float64
#  8   hepatitis_b                      649 non-null    float64
#  9   measles                          704 non-null    int64
#  10  bmi                              704 non-null    float64
#  11  under-five_deaths                704 non-null    int64
#  12  polio                            704 non-null    int64
#  13  total_expenditure                658 non-null    float64
#  14  diphtheria                       704 non-null    int64
#  15  hiv/aids                         704 non-null    float64
#  16  gdp                              612 non-null    float64
#  17  population                       496 non-null    float64
#  18  thinness__1-19_years             704 non-null    float64
#  19  thinness_5-9_years               704 non-null    float64
#  20  income_composition_of_resources  704 non-null    float64
#  21  schooling                        704 non-null    float64
# dtypes: float64(13), int64(7), object(2)
# memory usage: 121.1+ KB

# %%
country_list = df.country.unique()
interpolate_list =['life_expectancy', 'adult_mortality', 'infant_deaths', 'alcohol', 
                   'percentage_expenditure', 'hepatitis_b', 'measles', 'bmi', 'under-five_deaths', 
                   'polio', 'total_expenditure', 'diphtheria', 'hiv/aids', 'gdp', 'population', 
                   'thinness__1-19_years', 'thinness_5-9_years', 'income_composition_of_resources', 
                   'schooling']
for country in country_list:
    df.loc[df['country'] == country,interpolate_list] = df.loc[df['country'] == country,interpolate_list].interpolate()

# %%
df.isnull().sum()
# Out:
# country                              0
# year                                 0
# status                               0
# life_expectancy                      0
# adult_mortality                      0
# infant_deaths                        0
# alcohol                             42
# percentage_expenditure               0
# hepatitis_b                         16
# measles                              0
# bmi                                  0
# under-five_deaths                    0
# polio                                0
# total_expenditure                   43
# diphtheria                           0
# hiv/aids                             0
# gdp                                 88
# population                         208
# thinness__1-19_years                 0
# thinness_5-9_years                   0
# income_composition_of_resources      0
# schooling                            0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#          country  year      status  life_expectancy  adult_mortality  \
# 0    Afghanistan  2015  Developing             65.0              263
# 1    Afghanistan  2014  Developing             59.9              271
# 2    Afghanistan  2013  Developing             59.9              268
# 3    Afghanistan  2012  Developing             59.5              272
# 4    Afghanistan  2011  Developing             59.2              275
# ..           ...   ...         ...              ...              ...
# 667   Uzbekistan  2004  Developing             67.8              183
# 668   Uzbekistan  2003  Developing             67.2              183
# 669   Uzbekistan  2002  Developing             67.1              186
# 670   Uzbekistan  2001  Developing             67.4              185
# 671   Uzbekistan  2000  Developing             67.1              189
#
#      infant_deaths  alcohol  percentage_expenditure  hepatitis_b  measles  \
# 0               62     0.01               71.279624         65.0     1154
# 1               64     0.01               73.523582         62.0      492
# 2               66     0.01               73.219243         64.0      430
# 3               69     0.01               78.184215         67.0     2787
# 4               71     0.01                7.097109         68.0     3013
# ..             ...      ...                     ...          ...      ...
# 667             24     1.59               34.418872         99.0       75
# 668             25     1.54               28.521358         99.0       85
# 669             27     1.47               24.994387         62.0       25
# 670             28     1.53               43.663856         62.0       22
# 671             30     1.60               48.509417         62.0       80
#
#      ...  polio  total_expenditure  diphtheria  hiv/aids         gdp  \
# 0    ...      6               8.16          65       0.1  584.259210
# 1    ...     58               8.18          62       0.1  612.696514
# 2    ...     62               8.13          64       0.1  631.744976
# 3    ...     67               8.52          67       0.1  669.959000
# 4    ...     68               7.87          68       0.1   63.537231
# ..   ...    ...                ...         ...       ...         ...
# 667  ...     99               5.11          99       0.3  465.119887
# 668  ...     99               5.17          98       0.3  396.129969
# 669  ...     99               5.44          99       0.2  383.349500
# 670  ...     99               5.28          99       0.2  456.734892
# 671  ...     99               5.29          99       0.1  558.221144
#
#      population  thinness__1-19_years  thinness_5-9_years  \
# 0    33736494.0                  17.2                17.3
# 1      327582.0                  17.5                17.5
# 2    31731688.0                  17.7                17.7
# 3     3696958.0                  17.9                18.0
# 4     2978599.0                  18.2                18.2
# ..          ...                   ...                 ...
# 667   2586435.0                   3.2                 3.2
# 668   2556765.0                   3.3                 3.3
# 669   2527185.0                   3.3                 3.3
# 670   2496445.0                   3.4                 3.3
# 671     24654.0                   3.4                 3.4
#
#      income_composition_of_resources  schooling
# 0                              0.479       10.1
# 1                              0.476       10.0
# 2                              0.470        9.9
# 3                              0.463        9.8
# 4                              0.454        9.5
# ..                               ...        ...
# 667                            0.613       11.6
# 668                            0.607       11.3
# 669                            0.600       11.0
# 670                            0.594       10.7
# 671                            0.000       10.6
#
# [444 rows x 22 columns]

# %%
df1=df.copy()
df1.to_csv('cleaned.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 671
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          444 non-null    object
#  1   year                             444 non-null    int64
#  2   status                           444 non-null    object
#  3   life_expectancy                  444 non-null    float64
#  4   adult_mortality                  444 non-null    int64
#  5   infant_deaths                    444 non-null    int64
#  6   alcohol                          444 non-null    float64
#  7   percentage_expenditure           444 non-null    float64
#  8   hepatitis_b                      444 non-null    float64
#  9   measles                          444 non-null    int64
#  10  bmi                              444 non-null    float64
#  11  under-five_deaths                444 non-null    int64
#  12  polio                            444 non-null    int64
#  13  total_expenditure                444 non-null    float64
#  14  diphtheria                       444 non-null    int64
#  15  hiv/aids                         444 non-null    float64
#  16  gdp                              444 non-null    float64
#  17  population                       444 non-null    float64
#  18  thinness__1-19_years             444 non-null    float64
#  19  thinness_5-9_years               444 non-null    float64
#  20  income_composition_of_resources  444 non-null    float64
#  21  schooling                        444 non-null    float64
# dtypes: float64(13), int64(7), object(2)
# memory usage: 79.8+ KB

# %%
columns_dict={'life_expectancy': 1, 'adult_mortality': 2, 'infant_deaths': 3, 'alcohol': 4, 
                   'percentage_expenditure': 5, 'hepatitis_b': 6, 'measles': 7, 'bmi': 8, 'under-five_deaths': 9, 
                   'polio': 10, 'total_expenditure': 11, 'diphtheria': 12, 'hiv/aids': 13, 'gdp': 14, 'population': 15, 
                   'thinness__1-19_years': 16, 'thinness_5-9_years': 17, 'income_composition_of_resources': 18, 
                   'schooling':19}             
plt.figure(figsize=(20,30))
for variable,i in columns_dict.items():
  plt.subplot(5,4,i)
  plt.boxplot(df[variable])
  plt.title(variable)

plt.show()

# %%
def outlier_count(col, data=df):
    print(15*'-' + col + 15*'-')
    q75, q25 = np.percentile(data[col], [75, 25])
    iqr = q75 - q25
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    print('Number of outliers: {}'.format(outlier_count))
    print('Percent of data that is outlier: {}%'.format(outlier_percent))
for col in columns_dict:
    outlier_count(col)
# Out:
# ---------------life_expectancy---------------
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
# ---------------adult_mortality---------------
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
# ---------------infant_deaths---------------
# Number of outliers: 64
# Percent of data that is outlier: 14.41%
# ---------------alcohol---------------
# Number of outliers: 23
# Percent of data that is outlier: 5.18%
# ---------------percentage_expenditure---------------
# Number of outliers: 50
# Percent of data that is outlier: 11.26%
# ---------------hepatitis_b---------------
# Number of outliers: 44
# Percent of data that is outlier: 9.91%
# ---------------measles---------------
# Number of outliers: 62
# Percent of data that is outlier: 13.96%
# ---------------bmi---------------
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
# ---------------under-five_deaths---------------
# Number of outliers: 63
# Percent of data that is outlier: 14.19%
# ---------------polio---------------
# Number of outliers: 31
# Percent of data that is outlier: 6.98%
# ---------------total_expenditure---------------
# Number of outliers: 2
# Percent of data that is outlier: 0.45%
# ---------------diphtheria---------------
# Number of outliers: 24
# Percent of data that is outlier: 5.41%
# ---------------hiv/aids---------------
# Number of outliers: 111
# Percent of data that is outlier: 25.0%
# ---------------gdp---------------
# Number of outliers: 34
# Percent of data that is outlier: 7.66%
# ---------------population---------------
# Number of outliers: 54
# Percent of data that is outlier: 12.16%
# ---------------thinness__1-19_years---------------
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
# ---------------thinness_5-9_years---------------
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
# ---------------income_composition_of_resources---------------
# Number of outliers: 30
# Percent of data that is outlier: 6.76%
# ---------------schooling---------------
# Number of outliers: 8
# Percent of data that is outlier: 1.8%

# %%
for variable in columns_dict.keys():
    q75, q25 = np.percentile(df[variable], [75 ,25])
    iqr = q75 - q25

    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    print("Number of outliers and percentage of it in {} : {} and {}".format(variable,
                                                                             len((np.where((df[variable] > max_val) | 
                                                                                           (df[variable] < min_val))[0])),len((np.where((df[variable] > max_val) | 
                                                                                           (df[variable] < min_val))[0]))*100/1987))
# Out:
# Number of outliers and percentage of it in life_expectancy : 0 and 0.0
# Number of outliers and percentage of it in adult_mortality : 0 and 0.0
# Number of outliers and percentage of it in infant_deaths : 64 and 3.2209360845495723
# Number of outliers and percentage of it in alcohol : 23 and 1.1575239053850026
# Number of outliers and percentage of it in percentage_expenditure : 50 and 2.5163563160543534
# Number of outliers and percentage of it in hepatitis_b : 44 and 2.214393558127831
# Number of outliers and percentage of it in measles : 62 and 3.120281831907398
# Number of outliers and percentage of it in bmi : 0 and 0.0
# Number of outliers and percentage of it in under-five_deaths : 63 and 3.170608958228485
# Number of outliers and percentage of it in polio : 31 and 1.560140915953699
# Number of outliers and percentage of it in total_expenditure : 2 and 0.10065425264217413
# Number of outliers and percentage of it in diphtheria : 24 and 1.2078510317060895
# Number of outliers and percentage of it in hiv/aids : 111 and 5.586311021640665
# Number of outliers and percentage of it in gdp : 34 and 1.7111222949169602
# Number of outliers and percentage of it in population : 54 and 2.7176648213387016
# Number of outliers and percentage of it in thinness__1-19_years : 0 and 0.0
# Number of outliers and percentage of it in thinness_5-9_years : 0 and 0.0
# Number of outliers and percentage of it in income_composition_of_resources : 30 and 1.509813789632612
# Number of outliers and percentage of it in schooling : 8 and 0.40261701056869653

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_life_expectancy = df['life_expectancy']
plt.boxplot(original_life_expectancy)
plt.title("original_life_expectancy")

plt.subplot(1,2,2)
winsorized_life_expectancy = winsorize(df['life_expectancy'],(0.01,0))
plt.boxplot(winsorized_life_expectancy)
plt.title("winsorized_life_expectancy")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_adult_mortality = df['adult_mortality']
plt.boxplot(original_adult_mortality)
plt.title("original_adult_mortality")

plt.subplot(1,2,2)
winsorized_Adult_Mortality = winsorize(df['adult_mortality'],(0,0.03))
plt.boxplot(winsorized_Adult_Mortality)
plt.title("winsorized_Adult_Mortality")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_infant_deaths = df['infant_deaths']
plt.boxplot(original_infant_deaths)
plt.title("original_infant_deaths")

plt.subplot(1,2,2)
winsorized_Infant_Deaths = winsorize(df['infant_deaths'],(0,0.15))
plt.boxplot(winsorized_Infant_Deaths)
plt.title("winsorized_Infant_Deaths")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_alcohol = df['alcohol']
plt.boxplot(original_alcohol)
plt.title("original_alcohol")

plt.subplot(1,2,2)
winsorized_Alcohol = winsorize(df['alcohol'],(0,0.10))
plt.boxplot(winsorized_Alcohol)
plt.title("winsorized_Alcohol")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_percentage_exp = df['percentage_expenditure']
plt.boxplot(original_percentage_exp)
plt.title("original_percentage_exp")

plt.subplot(1,2,2)
winsorized_Percentage_Exp = winsorize(df['percentage_expenditure'],(0,0.12))
plt.boxplot(winsorized_Percentage_Exp)
plt.title("winsorized_Percentage_Exp")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_HepatitisB = df['hepatitis_b']
plt.boxplot(original_HepatitisB)
plt.title("original_HepatitisB")

plt.subplot(1,2,2)
winsorized_HepatitisB = winsorize(df['hepatitis_b'],(0.11,0))
plt.boxplot(winsorized_HepatitisB)
plt.title("winsorized_HepatitisB")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_Measles = df['measles']
plt.boxplot(original_Measles)
plt.title("original_Measles")

plt.subplot(1,2,2)
winsorized_Measles = winsorize(df['measles'],(0,0.14))
plt.boxplot(winsorized_Measles)
plt.title("winsorized_Measles")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_bmi = df['bmi']
plt.boxplot(original_bmi)
plt.title("original_bmi")

plt.subplot(1,2,2)
winsorized_bmi = winsorize(df['bmi'],(0.01,0))
plt.boxplot(winsorized_bmi)
plt.title("winsorized_bmi")
# Out:
# Text(0.5, 1.0, 'winsorized_bmi')

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_Under_Five_Deaths = df['under-five_deaths']
plt.boxplot(original_Under_Five_Deaths)
plt.title("original_Under_Five_Deaths")

plt.subplot(1,2,2)
winsorized_Under_Five_Deaths = winsorize(df['under-five_deaths'],(0,0.145))
plt.boxplot(winsorized_Under_Five_Deaths)
plt.title("winsorized_Under_Five_Deaths")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_Polio = df['polio']
plt.boxplot(original_Polio)
plt.title("original_Polio")

plt.subplot(1,2,2)
winsorized_Polio = winsorize(df['polio'],(0.09,0))
plt.boxplot(winsorized_Polio)
plt.title("winsorized_Polio")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_Tot_Exp = df['total_expenditure']
plt.boxplot(original_Tot_Exp)
plt.title("original_Tot_Exp")

plt.subplot(1,2,2)
winsorized_Tot_Exp = winsorize(df['total_expenditure'],(0,0.01))
plt.boxplot(winsorized_Tot_Exp)
plt.title("winsorized_Tot_Exp")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_Diphtheria = df['diphtheria']
plt.boxplot(original_Diphtheria)
plt.title("original_Diphtheria")

plt.subplot(1,2,2)
winsorized_Diphtheria = winsorize(df['diphtheria'],(0.10,0))
plt.boxplot(winsorized_Diphtheria)
plt.title("winsorized_Diphtheria")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_GDP = df['gdp']
plt.boxplot(original_GDP)
plt.title("original_GDP")

plt.subplot(1,2,2)
winsorized_GDP = winsorize(df['gdp'],(0,0.13))
plt.boxplot(winsorized_GDP)
plt.title("winsorized_GDP")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_Population = df['population']
plt.boxplot(original_Population)
plt.title("original_Population")

plt.subplot(1,2,2)
winsorized_Population = winsorize(df['population'],(0,0.14))
plt.boxplot(winsorized_Population)
plt.title("winsorized_Population")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_thinness_1to19_years = df['thinness__1-19_years']
plt.boxplot(original_thinness_1to19_years)
plt.title("original_thinness_1to19_years")

plt.subplot(1,2,2)
winsorized_thinness_1to19_years = winsorize(df['thinness__1-19_years'],(0,0.04))
plt.boxplot(winsorized_thinness_1to19_years)
plt.title("winsorized_thinness_1to19_years")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_Income_Comp_Of_Resources = df['income_composition_of_resources']
plt.boxplot(original_Income_Comp_Of_Resources)
plt.title("original_Income_Comp_Of_Resources")

plt.subplot(1,2,2)
winsorized_Income_Comp_Of_Resources = winsorize(df['income_composition_of_resources'],(0.10,0))
plt.boxplot(winsorized_Income_Comp_Of_Resources)
plt.title("winsorized_Income_Comp_Of_Resources")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_Schooling = df['schooling']
plt.boxplot(original_Schooling)
plt.title("original_Schooling")

plt.subplot(1,2,2)
winsorized_Schooling = winsorize(df['schooling'],(0.02,0.01))
plt.boxplot(winsorized_Schooling)
plt.title("winsorized_Schooling")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_thinness_5to9_years = df['thinness_5-9_years']
plt.boxplot(original_thinness_5to9_years)
plt.title("original_thinness_5to9_years")

plt.subplot(1,2,2)
winsorized_thinness_5to9_years = winsorize(df['thinness_5-9_years'],(0,0.04))
plt.boxplot(winsorized_thinness_5to9_years)
plt.title("winsorized_thinness_5to9_years")

plt.show()

# %%
from scipy.stats.mstats import winsorize
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
original_thinness_1to19_years = df['thinness__1-19_years']
plt.boxplot(original_thinness_1to19_years)
plt.title("original_thinness_1to19_years")

plt.subplot(1,2,2)
winsorized_thinness_1to19_years = winsorize(df['thinness__1-19_years'],(0,0.04))
plt.boxplot(winsorized_thinness_1to19_years)
plt.title("winsorized_thinness_1to19_years")

plt.show()

# %%
win_list = [winsorized_life_expectancy,winsorized_Adult_Mortality,winsorized_Infant_Deaths,winsorized_Alcohol,
            winsorized_Percentage_Exp,winsorized_HepatitisB,winsorized_Measles,winsorized_bmi,winsorized_Under_Five_Deaths,winsorized_Polio,winsorized_Tot_Exp,winsorized_Diphtheria,winsorized_GDP,winsorized_Population,winsorized_thinness_1to19_years,winsorized_thinness_5to9_years,winsorized_Income_Comp_Of_Resources,winsorized_Schooling]


for variable in win_list:
    q75, q25 = np.percentile(variable, [75 ,25])
    iqr = q75 - q25

    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    
    print("Number of outliers after winsorization : {}".format(len(np.where((variable > max_val) | (variable < min_val))[0])))
# Out:
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0
# Number of outliers after winsorization : 0

# %%
df.describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count   444.000000       444.000000       444.000000     444.000000
# mean   2006.954955        69.754279       148.639640      93.882883
# std       4.334517         5.391776        78.132901     265.075593
# min    2000.000000        54.800000         1.000000       0.000000
# 25%    2003.000000        65.900000        97.000000       2.000000
# 50%    2007.000000        69.100000       147.500000      10.000000
# 75%    2011.000000        73.800000       211.000000      57.250000
# max    2015.000000        84.000000       321.000000    1800.000000
#
#           alcohol  percentage_expenditure  hepatitis_b        measles  \
# count  444.000000              444.000000   444.000000     444.000000
# mean     2.172387              226.747865    76.702703    5971.069820
# std      2.557799              500.618181    28.178276   16464.124674
# min      0.010000                0.000000     2.000000       0.000000
# 25%      0.210000               20.617959    65.000000      11.000000
# 50%      1.460000               64.787773    89.000000     331.000000
# 75%      2.900000              211.930237    96.250000    3348.500000
# max     13.030000             4348.335310    99.000000  131441.000000
#
#               bmi  under-five_deaths       polio  total_expenditure  \
# count  444.000000         444.000000  444.000000         444.000000
# mean    31.831757         121.259009   83.222973           5.142703
# std     18.431796         351.712056   22.536999           2.008174
# min      1.400000           0.000000    5.000000           1.190000
# 25%     16.400000           2.000000   78.000000           3.700000
# 50%     26.350000          11.000000   93.000000           4.760000
# 75%     48.175000          72.500000   97.000000           6.392500
# max     65.400000        2500.000000   99.000000          13.730000
#
#        diphtheria    hiv/aids           gdp    population  \
# count  444.000000  444.000000    444.000000  4.440000e+02
# mean    84.094595    0.184685   2913.304401  3.038137e+07
# std     20.436326    0.245482   5474.851117  1.297063e+08
# min      5.000000    0.100000      1.681350  3.400000e+01
# 25%     78.750000    0.100000    362.138377  1.275398e+05
# 50%     92.000000    0.100000    990.469704  2.367374e+06
# 75%     97.000000    0.125000   3256.024385  1.420686e+07
# max     99.000000    2.200000  37582.846240  1.293859e+09
#
#        thinness__1-19_years  thinness_5-9_years  \
# count            444.000000          444.000000
# mean               7.939189            8.343243
# std                7.007529            7.083687
# min                0.900000            1.000000
# 25%                2.600000            2.900000
# 50%                4.800000            4.800000
# 75%               13.300000           13.625000
# max               27.700000           28.600000
#
#        income_composition_of_resources   schooling
# count                       444.000000  444.000000
# mean                          0.598577   11.324099
# std                           0.195177    2.218673
# min                           0.000000    0.000000
# 25%                           0.532000   10.100000
# 50%                           0.644000   11.600000
# 75%                           0.721250   12.825000
# max                           0.895000   16.000000

# %%
df['winsorized_Life_Expectancy'] = winsorized_life_expectancy
df['winsorized_Adult_Mortality'] = winsorized_Adult_Mortality
df['winsorized_Infant_Deaths'] = winsorized_Infant_Deaths
df['winsorized_Alcohol'] = winsorized_Alcohol
df['winsorized_Percentage_Exp'] = winsorized_Percentage_Exp
df['winsorized_HepatitisB'] = winsorized_HepatitisB
df['winsorized_measles'] = winsorized_Measles
df['winsorized_bmi'] = winsorized_bmi
df['winsorized_Under_Five_Deaths'] = winsorized_Under_Five_Deaths
df['winsorized_Polio'] = winsorized_Polio
df['winsorized_Tot_Exp'] = winsorized_Tot_Exp
df['winsorized_Diphtheria'] = winsorized_Diphtheria
df['winsorized_GDP'] = winsorized_GDP
df['winsorized_Population'] = winsorized_Population
df['winsorized_thinness_1to19_years'] = winsorized_thinness_1to19_years
df['winsorized_thinness_5to9_years'] = winsorized_thinness_5to9_years
df['winsorized_Income_Comp_Of_Resources'] = winsorized_Income_Comp_Of_Resources
df['winsorized_Schooling'] = winsorized_Schooling

# %%
df_win = df.iloc[:,22:]
df_win['country'] = df['country']
df_win['year'] = df['year']
df_win['status'] = df['status']
df_win_num = df_win.iloc[:,:-3]
cormat = df_win_num.corr()

# %%
import seaborn as sns

plt.figure(figsize=(15,15))
sns.heatmap(cormat, square=True, annot=True, linewidths=.5)
plt.title("Correlation matrix among winsorized variables")
plt.show()

# %%
ax = sns.countplot(df['status'], order = df['status'].value_counts().index)
plt.title('Distribution of countries per their statuses')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution of countries per their statuses')

# %%
columns_dict={'life_expectancy': 1, 'adult_mortality': 2, 'infant_deaths': 3, 'alcohol': 4, 
                   'percentage_expenditure': 5, 'hepatitis_b': 6, 'measles': 7, 'bmi': 8, 'under-five_deaths': 9, 
                   'polio': 10, 'total_expenditure': 11, 'diphtheria': 12, 'hiv/aids': 13, 'gdp': 14, 'population': 15, 
                   'thinness__1-19_years': 16, 'thinness_5-9_years': 17, 'income_composition_of_resources': 18, 
                   'schooling': 19}

plt.figure(figsize=(20,30) )

# make a histogram plot for each variable column
for variable,i in columns_dict.items():
  
  plt.subplot(5,4,i)
  sns.distplot(df[variable])
  sns.set(style='darkgrid')
  plt.title(variable)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
all_col = ['life_expectancy','winsorized_Life_Expectancy','adult_mortality','winsorized_Adult_Mortality','infant_deaths',
         'winsorized_Infant_Deaths','alcohol','winsorized_Alcohol','percentage_expenditure','winsorized_Percentage_Exp','hepatitis_b',
         'winsorized_HepatitisB','under-five_deaths','winsorized_Under_Five_Deaths','polio','winsorized_Polio','total_expenditure',
         'winsorized_Tot_Exp','diphtheria','winsorized_Diphtheria','hiv/aids','gdp','winsorized_GDP',
         'population','winsorized_Population','thinness__1-19_years','winsorized_thinness_1to19_years','thinness_5-9_years',
         'winsorized_thinness_5to9_years','income_composition_of_resources','winsorized_Income_Comp_Of_Resources',
         'schooling','winsorized_Schooling']

plt.figure(figsize=(15,75))

for i in range(len(all_col)):
    plt.subplot(18,2,i+1)
    plt.hist(df[all_col[i]])
    plt.title(all_col[i])

plt.show()

# %%
df_skew = df_win.drop('year', axis = 1)

print(df_skew.skew())
# Out:
# winsorized_Life_Expectancy             0.045161
# winsorized_Adult_Mortality            -0.187197
# winsorized_Infant_Deaths               1.268243
# winsorized_Alcohol                     0.893011
# winsorized_Percentage_Exp              1.132606
# winsorized_HepatitisB                 -1.079180
# winsorized_measles                     1.204864
# winsorized_bmi                         0.223590
# winsorized_Under_Five_Deaths           1.252072
# winsorized_Polio                      -0.952262
# winsorized_Tot_Exp                     0.397664
# winsorized_Diphtheria                 -0.729885
# winsorized_GDP                         0.917963
# winsorized_Population                  1.126226
# winsorized_thinness_1to19_years        0.820445
# winsorized_thinness_5to9_years         0.797930
# winsorized_Income_Comp_Of_Resources   -0.088327
# winsorized_Schooling                  -0.289831
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(df_skew.kurt())
# Out:
# winsorized_Life_Expectancy            -0.287945
# winsorized_Adult_Mortality            -0.749617
# winsorized_Infant_Deaths               0.014753
# winsorized_Alcohol                    -0.455057
# winsorized_Percentage_Exp             -0.110973
# winsorized_HepatitisB                 -0.150575
# winsorized_measles                    -0.205001
# winsorized_bmi                        -1.290113
# winsorized_Under_Five_Deaths          -0.045926
# winsorized_Polio                      -0.332843
# winsorized_Tot_Exp                    -0.546422
# winsorized_Diphtheria                 -0.832248
# winsorized_GDP                        -0.645067
# winsorized_Population                 -0.415270
# winsorized_thinness_1to19_years       -0.780231
# winsorized_thinness_5to9_years        -0.767621
# winsorized_Income_Comp_Of_Resources   -0.783577
# winsorized_Schooling                  -0.158657
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
df.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling',
#        'winsorized_Life_Expectancy', 'winsorized_Adult_Mortality',
#        'winsorized_Infant_Deaths', 'winsorized_Alcohol',
#        'winsorized_Percentage_Exp', 'winsorized_HepatitisB',
#        'winsorized_measles', 'winsorized_bmi', 'winsorized_Under_Five_Deaths',
#        'winsorized_Polio', 'winsorized_Tot_Exp', 'winsorized_Diphtheria',
#        'winsorized_GDP', 'winsorized_Population',
#        'winsorized_thinness_1to19_years', 'winsorized_thinness_5to9_years',
#        'winsorized_Income_Comp_Of_Resources', 'winsorized_Schooling'],
#       dtype='object')

# %%
needed= df.drop(['country','year','status'], axis=1)

# %%
df2=needed.drop(['life_expectancy'], axis=1)

# %%
# !pip install factor_analyzer==0.2.3
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value,p_value=calculate_bartlett_sphericity(df_win)
chi_square_value, p_value
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting factor_analyzer==0.2.3
#   Downloading factor_analyzer-0.2.3-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from factor_analyzer==0.2.3) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from factor_analyzer==0.2.3) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from factor_analyzer==0.2.3) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->factor_analyzer==0.2.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->factor_analyzer==0.2.3) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->factor_analyzer==0.2.3) (1.15.0)
# Installing collected packages: factor-analyzer
# Successfully installed factor-analyzer-0.2.3
# (8593.474793477733, 0.0)

# %%
from factor_analyzer.factor_analyzer import calculate_kmo
kmo_vars,kmo_model=calculate_kmo(df_win)
print(kmo_model)
# Out:
# 0.8204757973603609

# %%
from factor_analyzer import FactorAnalyzer
fa = FactorAnalyzer()
fa.analyze(df_win,17, rotation=None)

ev, v = fa.get_eigenvalues()
ev
# Out:
#     Original_Eigenvalues
# 0               7.395051
# 1               2.150697
# 2               1.748268
# 3               1.544055
# 4               1.068770
# 5               1.012504
# 6               0.803817
# 7               0.686126
# 8               0.565179
# 9               0.420066
# 10              0.381900
# 11              0.318680
# 12              0.292068
# 13              0.172844
# 14              0.139983
# 15              0.110919
# 16              0.097920
# 17              0.090638
# 18              0.000515

# %%
fa = FactorAnalyzer()
fa.analyze(df_win, 6, rotation="varimax")
fa.loadings
# Out:
#                                       Factor1   Factor2   Factor3   Factor4  \
# winsorized_Life_Expectancy           0.217835 -0.188352  0.310073  0.222407
# winsorized_Adult_Mortality          -0.063116  0.011762 -0.007336 -0.138389
# winsorized_Infant_Deaths            -0.173204  0.919155 -0.231860 -0.156908
# winsorized_Alcohol                   0.348547 -0.007850  0.375372  0.192670
# winsorized_Percentage_Exp            0.099375 -0.195740  0.168602  0.815257
# winsorized_HepatitisB                0.165429 -0.259913  0.587563  0.174152
# winsorized_measles                  -0.057662  0.709673 -0.152555 -0.025761
# winsorized_bmi                       0.541560 -0.385502 -0.025353  0.135555
# winsorized_Under_Five_Deaths        -0.183526  0.908900 -0.239213 -0.157670
# winsorized_Polio                     0.111229 -0.206652  0.871203  0.067225
# winsorized_Tot_Exp                   0.040465 -0.424961 -0.067823  0.061692
# winsorized_Diphtheria                0.104339 -0.219763  0.924848  0.082215
# winsorized_GDP                       0.210057 -0.089272  0.109813  0.911926
# winsorized_Population               -0.152458  0.426252 -0.196860  0.002934
# winsorized_thinness_1to19_years     -0.907391  0.145247 -0.151954 -0.085211
# winsorized_thinness_5to9_years      -0.867800  0.177898 -0.154600 -0.097296
# winsorized_Income_Comp_Of_Resources  0.472994 -0.168799  0.334809  0.230160
# winsorized_Schooling                 0.379126 -0.319850  0.384963  0.290774
# year                                -0.009717  0.006704  0.134238  0.130815
#
#                                       Factor5   Factor6
# winsorized_Life_Expectancy           0.855203  0.077999
# winsorized_Adult_Mortality          -0.631280 -0.033292
# winsorized_Infant_Deaths            -0.057007  0.025834
# winsorized_Alcohol                   0.154975 -0.094043
# winsorized_Percentage_Exp            0.233781  0.076129
# winsorized_HepatitisB                0.067566  0.383542
# winsorized_measles                   0.052653 -0.169416
# winsorized_bmi                       0.301919  0.130847
# winsorized_Under_Five_Deaths        -0.065373  0.020015
# winsorized_Polio                     0.121275  0.065616
# winsorized_Tot_Exp                   0.236988  0.040892
# winsorized_Diphtheria                0.103187  0.087472
# winsorized_GDP                       0.251939  0.157307
# winsorized_Population               -0.075429  0.111134
# winsorized_thinness_1to19_years     -0.075068  0.032140
# winsorized_thinness_5to9_years      -0.128997 -0.011950
# winsorized_Income_Comp_Of_Resources  0.571563  0.201948
# winsorized_Schooling                 0.465068  0.207998
# year                                 0.127880  0.787015

# %%
fa.get_factor_variance()
# Out:
#                  Factor1   Factor2   Factor3   Factor4   Factor5   Factor6
# SS Loadings     2.606710  3.109578  2.740715  1.887294  2.046854  0.971167
# Proportion Var  0.137195  0.163662  0.144248  0.099331  0.107729  0.051114
# Cumulative Var  0.137195  0.300857  0.445105  0.544437  0.652166  0.703280

# %%
fa = FactorAnalyzer()
fa.analyze(df_win, 5, rotation="varimax")
fa.loadings
# Out:
#                                       Factor1   Factor2   Factor3   Factor4  \
# winsorized_Life_Expectancy           0.234570 -0.188721  0.316763  0.230370
# winsorized_Adult_Mortality          -0.069224  0.009868 -0.013843 -0.143663
# winsorized_Infant_Deaths            -0.177968  0.926485 -0.215508 -0.141616
# winsorized_Alcohol                   0.372660 -0.022379  0.336827  0.153674
# winsorized_Percentage_Exp            0.122371 -0.197886  0.173945  0.787389
# winsorized_HepatitisB                0.147445 -0.253509  0.634399  0.230603
# winsorized_measles                  -0.038900  0.694053 -0.182875 -0.058989
# winsorized_bmi                       0.517981 -0.383853 -0.005785  0.159511
# winsorized_Under_Five_Deaths        -0.188026  0.916249 -0.223820 -0.143328
# winsorized_Polio                     0.137582 -0.211297  0.863671  0.055853
# winsorized_Tot_Exp                   0.030855 -0.424601 -0.060972  0.069648
# winsorized_Diphtheria                0.131102 -0.223948  0.922924  0.072438
# winsorized_GDP                       0.222644 -0.088484  0.126543  0.934055
# winsorized_Population               -0.167083  0.431003 -0.166899  0.031677
# winsorized_thinness_1to19_years     -0.923503  0.155617 -0.122984 -0.063522
# winsorized_thinness_5to9_years      -0.866158  0.187883 -0.136913 -0.086988
# winsorized_Income_Comp_Of_Resources  0.468317 -0.168803  0.360635  0.255416
# winsorized_Schooling                 0.375925 -0.320412  0.411235  0.315011
# year                                -0.039210  0.006011  0.244734  0.238610
#
#                                       Factor5
# winsorized_Life_Expectancy           0.828532
# winsorized_Adult_Mortality          -0.625561
# winsorized_Infant_Deaths            -0.046016
# winsorized_Alcohol                   0.128287
# winsorized_Percentage_Exp            0.220001
# winsorized_HepatitisB                0.106414
# winsorized_measles                   0.027978
# winsorized_bmi                       0.319410
# winsorized_Under_Five_Deaths        -0.054884
# winsorized_Polio                     0.102691
# winsorized_Tot_Exp                   0.246803
# winsorized_Diphtheria                0.084913
# winsorized_GDP                       0.238836
# winsorized_Population               -0.056987
# winsorized_thinness_1to19_years     -0.066145
# winsorized_thinness_5to9_years      -0.130262
# winsorized_Income_Comp_Of_Resources  0.585037
# winsorized_Schooling                 0.476236
# year                                 0.195037

# %%
fa.get_factor_variance()
# Out:
#                  Factor1   Factor2   Factor3   Factor4   Factor5
# SS Loadings     2.652069  3.125969  2.814957  1.959693  2.029318
# Proportion Var  0.139583  0.164525  0.148156  0.103142  0.106806
# Cumulative Var  0.139583  0.304107  0.452263  0.555405  0.662211

# %%
df_win['status'].value_counts()
# Out:
# 1    429
# 0     15
# Name: status, dtype: int64

# %%
from sklearn import preprocessing
l_encoder= preprocessing.LabelEncoder()
df_win.loc[:,'status'] = l_encoder.fit_transform(df_win.loc[:,'status'])
df_win['status'].value_counts()
# Out:
# 1    429
# 0     15
# Name: status, dtype: int64

# %%
df_win = pd.DataFrame(df_win)
df_win['country'] = df['country']
df_win['year'] = df['year']
df_win['status'] = df['status']
print(df_win)
# Out:
#      winsorized_Life_Expectancy  winsorized_Adult_Mortality  \
# 0                          65.0                         263
# 1                          59.9                         271
# 2                          59.9                         268
# 3                          59.5                         272
# 4                          59.2                         275
# ..                          ...                         ...
# 667                        67.8                         183
# 668                        67.2                         183
# 669                        67.1                         186
# 670                        67.4                         185
# 671                        67.1                         189
#
#      winsorized_Infant_Deaths  winsorized_Alcohol  winsorized_Percentage_Exp  \
# 0                          62                0.01                  71.279624
# 1                          64                0.01                  73.523582
# 2                          66                0.01                  73.219243
# 3                          69                0.01                  78.184215
# 4                          71                0.01                   7.097109
# ..                        ...                 ...                        ...
# 667                        24                1.59                  34.418872
# 668                        25                1.54                  28.521358
# 669                        27                1.47                  24.994387
# 670                        28                1.53                  43.663856
# 671                        30                1.60                  48.509417
#
#      winsorized_HepatitisB  winsorized_measles  winsorized_bmi  \
# 0                     65.0                1154            19.1
# 1                     62.0                 492            18.6
# 2                     64.0                 430            18.1
# 3                     67.0                2787            17.6
# 4                     68.0                3013            17.2
# ..                     ...                 ...             ...
# 667                   99.0                  75            37.0
# 668                   99.0                  85            36.4
# 669                   62.0                  25            35.9
# 670                   62.0                  22            35.3
# 671                   62.0                  80            34.8
#
#      winsorized_Under_Five_Deaths  winsorized_Polio  ...  \
# 0                              83                58  ...
# 1                              86                58  ...
# 2                              89                62  ...
# 3                              93                67  ...
# 4                              97                68  ...
# ..                            ...               ...  ...
# 667                            29                99  ...
# 668                            30                99  ...
# 669                            32                99  ...
# 670                            34                99  ...
# 671                            36                99  ...
#
#      winsorized_Diphtheria  winsorized_GDP  winsorized_Population  \
# 0                       65      584.259210             28112289.0
# 1                       65      612.696514               327582.0
# 2                       65      631.744976             28112289.0
# 3                       67      669.959000              3696958.0
# 4                       68       63.537231              2978599.0
# ..                     ...             ...                    ...
# 667                     99      465.119887              2586435.0
# 668                     98      396.129969              2556765.0
# 669                     99      383.349500              2527185.0
# 670                     99      456.734892              2496445.0
# 671                     99      558.221144                24654.0
#
#      winsorized_thinness_1to19_years  winsorized_thinness_5to9_years  \
# 0                               17.2                            17.3
# 1                               17.5                            17.5
# 2                               17.7                            17.7
# 3                               17.9                            18.0
# 4                               18.2                            18.2
# ..                               ...                             ...
# 667                              3.2                             3.2
# 668                              3.3                             3.3
# 669                              3.3                             3.3
# 670                              3.4                             3.3
# 671                              3.4                             3.4
#
#      winsorized_Income_Comp_Of_Resources  winsorized_Schooling      country  \
# 0                                  0.479                  10.1  Afghanistan
# 1                                  0.476                  10.0  Afghanistan
# 2                                  0.470                   9.9  Afghanistan
# 3                                  0.463                   9.8  Afghanistan
# 4                                  0.454                   9.5  Afghanistan
# ..                                   ...                   ...          ...
# 667                                0.613                  11.6   Uzbekistan
# 668                                0.607                  11.3   Uzbekistan
# 669                                0.600                  11.0   Uzbekistan
# 670                                0.594                  10.7   Uzbekistan
# 671                                0.434                  10.6   Uzbekistan
#
#      year      status
# 0    2015  Developing
# 1    2014  Developing
# 2    2013  Developing
# 3    2012  Developing
# 4    2011  Developing
# ..    ...         ...
# 667  2004  Developing
# 668  2003  Developing
# 669  2002  Developing
# 670  2001  Developing
# 671  2000  Developing
#
# [444 rows x 21 columns]

# %%
df1 =df_win.drop(labels=['winsorized_Percentage_Exp', 'winsorized_Income_Comp_Of_Resources', 
                'winsorized_thinness_5to9_years', 'winsorized_Infant_Deaths','winsorized_HepatitisB','winsorized_measles'], axis=1)
df1
# Out:
#      winsorized_Life_Expectancy  winsorized_Adult_Mortality  \
# 0                          65.0                         263
# 1                          59.9                         271
# 2                          59.9                         268
# 3                          59.5                         272
# 4                          59.2                         275
# ..                          ...                         ...
# 667                        67.8                         183
# 668                        67.2                         183
# 669                        67.1                         186
# 670                        67.4                         185
# 671                        67.1                         189
#
#      winsorized_Alcohol  winsorized_bmi  winsorized_Under_Five_Deaths  \
# 0                  0.01            19.1                            83
# 1                  0.01            18.6                            86
# 2                  0.01            18.1                            89
# 3                  0.01            17.6                            93
# 4                  0.01            17.2                            97
# ..                  ...             ...                           ...
# 667                1.59            37.0                            29
# 668                1.54            36.4                            30
# 669                1.47            35.9                            32
# 670                1.53            35.3                            34
# 671                1.60            34.8                            36
#
#      winsorized_Polio  winsorized_Tot_Exp  winsorized_Diphtheria  \
# 0                  58                8.16                     65
# 1                  58                8.18                     65
# 2                  62                8.13                     65
# 3                  67                8.52                     67
# 4                  68                7.87                     68
# ..                ...                 ...                    ...
# 667                99                5.11                     99
# 668                99                5.17                     98
# 669                99                5.44                     99
# 670                99                5.28                     99
# 671                99                5.29                     99
#
#      winsorized_GDP  winsorized_Population  winsorized_thinness_1to19_years  \
# 0        584.259210             28112289.0                             17.2
# 1        612.696514               327582.0                             17.5
# 2        631.744976             28112289.0                             17.7
# 3        669.959000              3696958.0                             17.9
# 4         63.537231              2978599.0                             18.2
# ..              ...                    ...                              ...
# 667      465.119887              2586435.0                              3.2
# 668      396.129969              2556765.0                              3.3
# 669      383.349500              2527185.0                              3.3
# 670      456.734892              2496445.0                              3.4
# 671      558.221144                24654.0                              3.4
#
#      winsorized_Schooling      country  year      status
# 0                    10.1  Afghanistan  2015  Developing
# 1                    10.0  Afghanistan  2014  Developing
# 2                     9.9  Afghanistan  2013  Developing
# 3                     9.8  Afghanistan  2012  Developing
# 4                     9.5  Afghanistan  2011  Developing
# ..                    ...          ...   ...         ...
# 667                  11.6   Uzbekistan  2004  Developing
# 668                  11.3   Uzbekistan  2003  Developing
# 669                  11.0   Uzbekistan  2002  Developing
# 670                  10.7   Uzbekistan  2001  Developing
# 671                  10.6   Uzbekistan  2000  Developing
#
# [444 rows x 15 columns]

# %%
y = df_win['winsorized_Life_Expectancy']
df = df_win.drop(labels='winsorized_Life_Expectancy', axis=1)
df
# Out:
#      winsorized_Adult_Mortality  winsorized_Infant_Deaths  winsorized_Alcohol  \
# 0                           263                        62                0.01
# 1                           271                        64                0.01
# 2                           268                        66                0.01
# 3                           272                        69                0.01
# 4                           275                        71                0.01
# ..                          ...                       ...                 ...
# 667                         183                        24                1.59
# 668                         183                        25                1.54
# 669                         186                        27                1.47
# 670                         185                        28                1.53
# 671                         189                        30                1.60
#
#      winsorized_Percentage_Exp  winsorized_HepatitisB  winsorized_measles  \
# 0                    71.279624                   65.0                1154
# 1                    73.523582                   62.0                 492
# 2                    73.219243                   64.0                 430
# 3                    78.184215                   67.0                2787
# 4                     7.097109                   68.0                3013
# ..                         ...                    ...                 ...
# 667                  34.418872                   99.0                  75
# 668                  28.521358                   99.0                  85
# 669                  24.994387                   62.0                  25
# 670                  43.663856                   62.0                  22
# 671                  48.509417                   62.0                  80
#
#      winsorized_bmi  winsorized_Under_Five_Deaths  winsorized_Polio  \
# 0              19.1                            83                58
# 1              18.6                            86                58
# 2              18.1                            89                62
# 3              17.6                            93                67
# 4              17.2                            97                68
# ..              ...                           ...               ...
# 667            37.0                            29                99
# 668            36.4                            30                99
# 669            35.9                            32                99
# 670            35.3                            34                99
# 671            34.8                            36                99
#
#      winsorized_Tot_Exp  winsorized_Diphtheria  winsorized_GDP  \
# 0                  8.16                     65      584.259210
# 1                  8.18                     65      612.696514
# 2                  8.13                     65      631.744976
# 3                  8.52                     67      669.959000
# 4                  7.87                     68       63.537231
# ..                  ...                    ...             ...
# 667                5.11                     99      465.119887
# 668                5.17                     98      396.129969
# 669                5.44                     99      383.349500
# 670                5.28                     99      456.734892
# 671                5.29                     99      558.221144
#
#      winsorized_Population  winsorized_thinness_1to19_years  \
# 0               28112289.0                             17.2
# 1                 327582.0                             17.5
# 2               28112289.0                             17.7
# 3                3696958.0                             17.9
# 4                2978599.0                             18.2
# ..                     ...                              ...
# 667              2586435.0                              3.2
# 668              2556765.0                              3.3
# 669              2527185.0                              3.3
# 670              2496445.0                              3.4
# 671                24654.0                              3.4
#
#      winsorized_thinness_5to9_years  winsorized_Income_Comp_Of_Resources  \
# 0                              17.3                                0.479
# 1                              17.5                                0.476
# 2                              17.7                                0.470
# 3                              18.0                                0.463
# 4                              18.2                                0.454
# ..                              ...                                  ...
# 667                             3.2                                0.613
# 668                             3.3                                0.607
# 669                             3.3                                0.600
# 670                             3.3                                0.594
# 671                             3.4                                0.434
#
#      winsorized_Schooling      country  year      status
# 0                    10.1  Afghanistan  2015  Developing
# 1                    10.0  Afghanistan  2014  Developing
# 2                     9.9  Afghanistan  2013  Developing
# 3                     9.8  Afghanistan  2012  Developing
# 4                     9.5  Afghanistan  2011  Developing
# ..                    ...          ...   ...         ...
# 667                  11.6   Uzbekistan  2004  Developing
# 668                  11.3   Uzbekistan  2003  Developing
# 669                  11.0   Uzbekistan  2002  Developing
# 670                  10.7   Uzbekistan  2001  Developing
# 671                  10.6   Uzbekistan  2000  Developing
#
# [444 rows x 20 columns]

# %%
y = y.to_numpy(dtype='float64')
y
# Out:
# array([65. , 59.9, 59.9, 59.5, 59.2, 58.8, 58.6, 58.1, 57.5, 57.3, 57.3,
#        57. , 57. , 57. , 57. , 57. , 74.6, 74.4, 74.4, 73.9, 73.5, 73.3,
#        73.2, 73.5, 72.9, 73. , 73. , 72.7, 72.6, 72.6, 72. , 72.5, 72.2,
#        71.9, 71.6, 71.1, 78. , 73. , 73. , 69.2, 68.4, 68.4, 67.8, 67.8,
#        67.5, 66.6, 71.4, 71. , 77. , 73. , 69.9, 69.5, 69.1, 68.6, 68.2,
#        67.8, 67.3, 66.8, 66.3, 65.8, 65.3, 69.4, 69.1, 68.7, 68.3, 67.9,
#        67.4, 67. , 66.5, 65.8, 65. , 64.2, 63.3, 62.5, 61.7, 62. , 68.3,
#        67.8, 67.4, 67. , 66.6, 66.1, 65.6, 65. , 64.1, 62.9, 61.5, 63. ,
#        59.3, 58.5, 57.7, 75.8, 75.6, 75.4, 75.2, 75. , 74.9, 74.5, 74.4,
#        74.2, 73.9, 73.5, 73.1, 72.7, 72.2, 71.7, 83. , 81. , 80. , 79.7,
#        79.5, 79.3, 79.1, 78.9, 78.8, 78.7, 78.6, 78.5, 78.4, 78.2, 78.1,
#        74.5, 74.5, 74.2, 73.9, 73.8, 73.2, 73.9, 74.4, 73.9, 73.9, 72.3,
#        72.7, 71.7, 73. , 71.8, 68. , 67.6, 67.3, 66.8, 66.4, 66. , 65.5,
#        65.2, 64.8, 64.4, 64. , 63.7, 63.3, 62.9, 62.5, 68.9, 68.7, 68.5,
#        68.3, 68.1, 67.9, 67.7, 67.5, 67.3, 67.2, 65.3, 66.9, 66.7, 66.5,
#        66.3, 67.9, 69.5, 76. , 77. , 76. , 74. , 69.3, 65.9, 64.7, 66.8,
#        67.2, 66.5, 74. , 72. , 70. , 82.2, 82.1, 81.8, 81.8, 81.7, 81.5,
#        81. , 84. , 84. , 80. , 81. , 79.7, 79.3, 79.3, 78.9, 74. , 73.9,
#        73.7, 73.6, 73.4, 73.3, 73.1, 73. , 72.8, 72.4, 72.5, 72.3, 72.1,
#        71.9, 71.7, 69.9, 69.5, 69.1, 68.5, 67.8, 67.8, 66.6, 65.3, 65. ,
#        64.6, 64.7, 64.4, 64.7, 64.4, 63.9, 74.8, 74.9, 75. , 75. , 74.9,
#        74.7, 74.5, 74.4, 74.1, 73.9, 73.7, 73.5, 73.2, 73. , 72.7, 74.8,
#        74.6, 74.5, 74.3, 74.1, 74. , 73.8, 73.7, 73.6, 73.4, 73.2, 73.1,
#        72.9, 72.7, 72.4, 78.2, 77.9, 77.6, 77.3, 76.7, 76.3, 75.9, 75.4,
#        75. , 74.3, 73.4, 72.7, 71.8, 78. , 69.6, 68.4, 68.1, 67.8, 67.3,
#        66.3, 66.9, 67.4, 65.9, 65. , 64.5, 64. , 64. , 63.8, 63.2, 62.8,
#        66.4, 66.2, 65.9, 65.6, 65.4, 65.2, 59.2, 64.5, 64.2, 63.9, 63.5,
#        63.2, 62.8, 62.5, 62.1, 69.6, 69.3, 68.9, 68.4, 68. , 67.5, 67. ,
#        66.6, 66. , 65.4, 64.7, 64.3, 63.1, 63.2, 62.5, 66.2, 66. , 65.7,
#        65.5, 65.1, 64.8, 64.6, 64.4, 64.2, 62.9, 63.7, 63.5, 63.2, 63. ,
#        62.8, 68.4, 68.1, 68.1, 68. , 67.9, 68. , 67.5, 67.5, 67.3, 67. ,
#        67.3, 67.2, 66.8, 66.8, 66.8, 74.7, 74.6, 74.5, 74.5, 74.5, 71.8,
#        72.3, 73.7, 73.8, 74.2, 69.1, 73.9, 73.7, 72.7, 71.5, 73.8, 73.7,
#        73.5, 73.2, 73. , 72.8, 72.7, 72.6, 69.6, 69.3, 68.8, 68.1, 67.3,
#        66.7, 66.4, 66.1, 65.9, 65.5, 65.9, 65.2, 64.3, 64. , 63.7, 74.6,
#        74.5, 74.3, 74.1, 73.9, 73.7, 73.5, 73.3, 73. , 72.5, 71.6, 71.7,
#        71.4, 71.2, 71.1, 75.5, 75.2, 74.8, 74.5, 74.2, 73.9, 73.5, 73.2,
#        72.8, 72.4, 72. , 71.6, 71.2, 78. , 74. , 66. , 65.4, 65.6, 65.6,
#        65.8, 65.6, 64.5, 64.1, 63.7, 63.3, 63.5, 63.4, 63.3, 64. , 63.8,
#        69.2, 69.1, 68.8, 68.5, 68.3, 68. , 67.9, 67.8, 67.6, 67.3, 67.8,
#        67.2, 67.1, 67.4, 67.1])

# %%
from sklearn import model_selection

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(df, y, test_size=0.2, random_state=42)
x_valid, x_test, y_valid, y_test = model_selection.train_test_split(x_test, y_test, test_size=0.5, random_state=42)
print(f'X_train shape -->{x_train.shape}')
print(f'X_valid shape -->{x_valid.shape}')
print(f'X_test shape -->{x_test.shape}')
print(f'y_train shape -->{y_train.shape}')
print(f'y_valid shape -->{y_valid.shape}')
print(f'y_test shape -->{y_test.shape}')
# Out:
# X_train shape -->(355, 20)
# X_valid shape -->(44, 20)
# X_test shape -->(45, 20)
# y_train shape -->(355,)
# y_valid shape -->(44,)
# y_test shape -->(45,)
