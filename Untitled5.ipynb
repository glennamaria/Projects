# %% [markdown]
# <a href="https://colab.research.google.com/github/glennamaria/task1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
path ="/content/drive/MyDrive/dataset"
df = pd.read_csv(path)

df.describe
# Out:
# <bound method NDFrame.describe of          Country  Year      Status  Life expectancy   Adult Mortality  \
# 0    Afghanistan  2015  Developing              65.0              263
# 1    Afghanistan  2014  Developing              59.9              271
# 2    Afghanistan  2013  Developing              59.9              268
# 3    Afghanistan  2012  Developing              59.5              272
# 4    Afghanistan  2011  Developing              59.2              275
# ..           ...   ...         ...               ...              ...
# 699        Yemen  2004  Developing              62.2              247
# 700        Yemen  2003  Developing              61.9              249
# 701        Yemen  2002  Developing              61.5               25
# 702        Yemen  2001  Developing              61.1              251
# 703        Yemen  2000  Developing              68.0              252
#
#      infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0               62     0.01               71.279624         65.0      1154
# 1               64     0.01               73.523582         62.0       492
# 2               66     0.01               73.219243         64.0       430
# 3               69     0.01               78.184215         67.0      2787
# 4               71     0.01                7.097109         68.0      3013
# ..             ...      ...                     ...          ...       ...
# 699             42     0.06                0.000000         43.0     12708
# 700             43     0.04                0.000000         38.0      8536
# 701             45     0.07                0.000000         31.0       890
# 702             46     0.08                0.000000         19.0       485
# 703             48     0.07                0.000000         14.0         0
#
#      ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0    ...      6               8.16           65        0.1  584.259210
# 1    ...     58               8.18           62        0.1  612.696514
# 2    ...     62               8.13           64        0.1  631.744976
# 3    ...     67               8.52           67        0.1  669.959000
# 4    ...     68               7.87           68        0.1   63.537231
# ..   ...    ...                ...          ...        ...         ...
# 699  ...     72               4.90           72        0.1         NaN
# 700  ...     61               5.00           61        0.1         NaN
# 701  ...     64               4.22           65        0.1         NaN
# 702  ...     73               4.34           73        0.1         NaN
# 703  ...     74               4.14           74        0.1         NaN
#
#      Population   thinness  1-19 years   thinness 5-9 years  \
# 0    33736494.0                   17.2                 17.3
# 1      327582.0                   17.5                 17.5
# 2    31731688.0                   17.7                 17.7
# 3     3696958.0                   17.9                 18.0
# 4     2978599.0                   18.2                 18.2
# ..          ...                    ...                  ...
# 699         NaN                   13.9                 13.9
# 700         NaN                   14.0                 13.9
# 701         NaN                   14.0                 14.0
# 702         NaN                   14.0                 14.0
# 703         NaN                   14.1                 14.1
#
#      Income composition of resources  Schooling
# 0                              0.479       10.1
# 1                              0.476       10.0
# 2                              0.470        9.9
# 3                              0.463        9.8
# 4                              0.454        9.5
# ..                               ...        ...
# 699                            0.464        8.4
# 700                            0.457        8.2
# 701                            0.450        8.0
# 702                            0.444        7.9
# 703                            0.436        7.7
#
# [704 rows x 22 columns]>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats.mstats import winsorize
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import os
# %matplotlib inline

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0              263
# 1  Afghanistan  2014  Developing              59.9              271
# 2  Afghanistan  2013  Developing              59.9              268
# 3  Afghanistan  2012  Developing              59.5              272
# 4  Afghanistan  2011  Developing              59.2              275
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0      6               8.16           65        0.1  584.259210  33736494.0
# 1     58               8.18           62        0.1  612.696514    327582.0
# 2     62               8.13           64        0.1  631.744976  31731688.0
# 3     67               8.52           67        0.1  669.959000   3696958.0
# 4     68               7.87           68        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
orig_cols = list(df.columns)
new_cols = []
for col in orig_cols:
    new_cols.append(col.strip().replace('  ', ' ').replace(' ', '_').lower())
df.columns = new_cols

# %%
df.rename(columns={'thinness_1-19_years':'thinness_10-19_years'}, inplace=True)

# %%
df.describe().iloc[:, 1:]
# Out:
#        life_expectancy  adult_mortality  infant_deaths     alcohol  \
# count       704.000000       704.000000     704.000000  662.000000
# mean         71.175284       133.276989      64.697443    1.996994
# std           5.782441        78.233274     217.157613    2.406438
# min          54.800000         1.000000       0.000000    0.010000
# 25%          66.675000        74.000000       1.000000    0.112500
# 50%          72.700000       132.000000       7.000000    1.375000
# 75%          74.900000       189.000000      30.000000    2.757500
# max          87.000000       321.000000    1800.000000   13.030000
#
#        percentage_expenditure  hepatitis_b        measles         bmi  \
# count              704.000000   649.000000     704.000000  704.000000
# mean               493.776972    83.841294    4461.759943   34.680398
# std               1169.208395    22.420045   13953.191523   19.503336
# min                  0.000000     2.000000       0.000000    1.000000
# 25%                  6.060366    78.000000       9.750000   17.275000
# 50%                 63.813282    95.000000     140.000000   33.450000
# 75%                283.449078    98.000000    1822.750000   52.800000
# max               9498.729062    99.000000  131441.000000   71.400000
#
#        under-five_deaths       polio  total_expenditure  diphtheria  \
# count         704.000000  704.000000         658.000000  704.000000
# mean           83.250000   85.696023           4.827614   86.313920
# std           287.251858   21.370103           1.982878   19.469553
# min             0.000000    5.000000           1.170000    5.000000
# 25%             1.000000   82.000000           3.400000   81.750000
# 50%             8.000000   95.000000           4.480000   95.000000
# 75%            37.000000   98.000000           5.937500   98.000000
# max          2500.000000   99.000000          13.730000   99.000000
#
#          hiv/aids           gdp    population  thinness_10-19_years  \
# count  704.000000    612.000000  4.960000e+02            704.000000
# mean     0.158523   7553.961337  2.829561e+07              7.417330
# std      0.199818  13860.093640  1.234376e+08              6.165839
# min      0.100000      1.681350  3.400000e+01              0.900000
# 25%      0.100000    538.374968  1.271760e+05              2.800000
# 50%      0.100000   1770.871290  1.874962e+06              5.150000
# 75%      0.100000   5691.199648  1.268933e+07             11.000000
# max      2.200000  88564.822980  1.293859e+09             27.700000
#
#        thinness_5-9_years  income_composition_of_resources   schooling
# count          704.000000                       704.000000  704.000000
# mean             7.663352                         0.646085   11.775994
# std              6.284103                         0.185160    2.194343
# min              1.000000                         0.000000    0.000000
# 25%              3.000000                         0.572750   10.500000
# 50%              5.100000                         0.674500   12.000000
# 75%             11.200000                         0.765250   13.300000
# max             28.600000                         0.924000   16.100000

# %%
plt.figure(figsize=(15,10))
for i, col in enumerate(['adult_mortality', 'infant_deaths', 'bmi', 'under-five_deaths', 'gdp', 'population'], start=1):
    plt.subplot(2, 3, i)
    df.boxplot(col)

# %%
mort_5_percentile = np.percentile(df.adult_mortality.dropna(), 5)
df.adult_mortality = df.apply(lambda x: np.nan if x.adult_mortality < mort_5_percentile else x.adult_mortality, axis=1)
df.infant_deaths = df.infant_deaths.replace(0, np.nan)
df.bmi = df.apply(lambda x: np.nan if (x.bmi < 10 or x.bmi > 50) else x.bmi, axis=1)
df['under-five_deaths'] = df['under-five_deaths'].replace(0, np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          704 non-null    object
#  1   year                             704 non-null    int64
#  2   status                           704 non-null    object
#  3   life_expectancy                  704 non-null    float64
#  4   adult_mortality                  670 non-null    float64
#  5   infant_deaths                    594 non-null    float64
#  6   alcohol                          662 non-null    float64
#  7   percentage_expenditure           704 non-null    float64
#  8   hepatitis_b                      649 non-null    float64
#  9   measles                          704 non-null    int64
#  10  bmi                              436 non-null    float64
#  11  under-five_deaths                607 non-null    float64
#  12  polio                            704 non-null    int64
#  13  total_expenditure                658 non-null    float64
#  14  diphtheria                       704 non-null    int64
#  15  hiv/aids                         704 non-null    float64
#  16  gdp                              612 non-null    float64
#  17  population                       496 non-null    float64
#  18  thinness_10-19_years             704 non-null    float64
#  19  thinness_5-9_years               704 non-null    float64
#  20  income_composition_of_resources  704 non-null    float64
#  21  schooling                        704 non-null    float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 121.1+ KB

# %%
def nulls_breakdown(df=df):
    df_cols = list(df.columns)
    cols_total_count = len(list(df.columns))
    cols_count = 0
    for loc, col in enumerate(df_cols):
        null_count = df[col].isnull().sum()
        total_count = df[col].isnull().count()
        percent_null = round(null_count/total_count*100, 2)
        if null_count > 0:
            cols_count += 1
            print('[iloc = {}] {} has {} null values: {}% null'.format(loc, col, null_count, percent_null))
    cols_percent_null = round(cols_count/cols_total_count*100, 2)
    print('Out of {} total columns, {} contain null values; {}% columns contain null values.'.format(cols_total_count, cols_count, cols_percent_null))

# %%
nulls_breakdown()
# Out:
# [iloc = 4] adult_mortality has 34 null values: 4.83% null
# [iloc = 5] infant_deaths has 110 null values: 15.62% null
# [iloc = 6] alcohol has 42 null values: 5.97% null
# [iloc = 8] hepatitis_b has 55 null values: 7.81% null
# [iloc = 10] bmi has 268 null values: 38.07% null
# [iloc = 11] under-five_deaths has 97 null values: 13.78% null
# [iloc = 13] total_expenditure has 46 null values: 6.53% null
# [iloc = 16] gdp has 92 null values: 13.07% null
# [iloc = 17] population has 208 null values: 29.55% null
# Out of 22 total columns, 9 contain null values; 40.91% columns contain null values.

# %%
df.drop(columns='bmi', inplace=True)

# %%
imputed_data = []
for year in list(df.year.unique()):
    year_data = df[df.year == year].copy()
    for col in list(year_data.columns)[3:]:
        year_data[col] = year_data[col].fillna(year_data[col].dropna().mean()).copy()
    imputed_data.append(year_data)
df = pd.concat(imputed_data).copy()

# %%
nulls_breakdown(df)
# Out:
# Out of 21 total columns, 0 contain null values; 0.0% columns contain null values.

# %%
cont_vars = list(df.columns)[3:]
def outliers_visual(data):
    plt.figure(figsize=(15, 40))
    i = 0
    for col in cont_vars:
        i += 1
        plt.subplot(9, 4, i)
        plt.boxplot(data[col])
        plt.title('{} boxplot'.format(col))
        i += 1
        plt.subplot(9, 4, i)
        plt.hist(data[col])
        plt.title('{} histogram'.format(col))
    plt.show()
outliers_visual(df)

# %%
def outlier_count(col, data=df):
    print(15*'-' + col + 15*'-')
    q75, q25 = np.percentile(data[col], [75, 25])
    iqr = q75 - q25
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    print('Number of outliers: {}'.format(outlier_count))
    print('Percent of data that is outlier: {}%'.format(outlier_percent))

# %%
for col in cont_vars:
    outlier_count(col)
# Out:
# ---------------life_expectancy---------------
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
# ---------------adult_mortality---------------
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
# ---------------infant_deaths---------------
# Number of outliers: 61
# Percent of data that is outlier: 8.66%
# ---------------alcohol---------------
# Number of outliers: 48
# Percent of data that is outlier: 6.82%
# ---------------percentage_expenditure---------------
# Number of outliers: 112
# Percent of data that is outlier: 15.91%
# ---------------hepatitis_b---------------
# Number of outliers: 49
# Percent of data that is outlier: 6.96%
# ---------------measles---------------
# Number of outliers: 116
# Percent of data that is outlier: 16.48%
# ---------------under-five_deaths---------------
# Number of outliers: 60
# Percent of data that is outlier: 8.52%
# ---------------polio---------------
# Number of outliers: 51
# Percent of data that is outlier: 7.24%
# ---------------total_expenditure---------------
# Number of outliers: 2
# Percent of data that is outlier: 0.28%
# ---------------diphtheria---------------
# Number of outliers: 42
# Percent of data that is outlier: 5.97%
# ---------------hiv/aids---------------
# Number of outliers: 138
# Percent of data that is outlier: 19.6%
# ---------------gdp---------------
# Number of outliers: 88
# Percent of data that is outlier: 12.5%
# ---------------population---------------
# Number of outliers: 74
# Percent of data that is outlier: 10.51%
# ---------------thinness_10-19_years---------------
# Number of outliers: 16
# Percent of data that is outlier: 2.27%
# ---------------thinness_5-9_years---------------
# Number of outliers: 16
# Percent of data that is outlier: 2.27%
# ---------------income_composition_of_resources---------------
# Number of outliers: 31
# Percent of data that is outlier: 4.4%
# ---------------schooling---------------
# Number of outliers: 10
# Percent of data that is outlier: 1.42%

# %%
def test_wins(col, lower_limit=0, upper_limit=0, show_plot=True):
    wins_data = winsorize(df[col], limits=(lower_limit, upper_limit))
    wins_dict[col] = wins_data
    if show_plot == True:
        plt.figure(figsize=(15,5))
        plt.subplot(121)
        plt.boxplot(df[col])
        plt.title('original {}'.format(col))
        plt.subplot(122)
        plt.boxplot(wins_data)
        plt.title('wins=({},{}) {}'.format(lower_limit, upper_limit, col))
        plt.show()

# %%
wins_dict = {}
test_wins(cont_vars[0], lower_limit=.01, show_plot=True)
test_wins(cont_vars[1], upper_limit=.04, show_plot=False)
test_wins(cont_vars[2], upper_limit=.05, show_plot=False)
test_wins(cont_vars[3], upper_limit=.0025, show_plot=False)
test_wins(cont_vars[4], upper_limit=.135, show_plot=False)
test_wins(cont_vars[5], lower_limit=.1, show_plot=False)
test_wins(cont_vars[6], upper_limit=.19, show_plot=False)
test_wins(cont_vars[7], upper_limit=.05, show_plot=False)
test_wins(cont_vars[8], lower_limit=.1, show_plot=False)
test_wins(cont_vars[9], upper_limit=.02, show_plot=False)
test_wins(cont_vars[10], lower_limit=.105, show_plot=False)
test_wins(cont_vars[11], upper_limit=.185, show_plot=False)
test_wins(cont_vars[12], upper_limit=.105, show_plot=False)
test_wins(cont_vars[13], upper_limit=.07, show_plot=False)
test_wins(cont_vars[14], upper_limit=.035, show_plot=False)
test_wins(cont_vars[15], upper_limit=.035, show_plot=False)
test_wins(cont_vars[16], lower_limit=.05, show_plot=False)
test_wins(cont_vars[17], lower_limit=.025, upper_limit=.005, show_plot=False)

# %%
plt.figure(figsize=(15,5))
for i, col in enumerate(cont_vars, 1):
    plt.subplot(2, 9, i)
    plt.boxplot(wins_dict[col])
plt.tight_layout()
plt.show()

# %%
wins_df = df.iloc[:, 0:3]
for col in cont_vars:
    wins_df[col] = wins_dict[col]

# %%
wins_df.describe()
# Out:
#              year  life_expectancy  adult_mortality  infant_deaths  \
# count   704.00000       704.000000       704.000000     704.000000
# mean   2007.50000        71.186506       138.979186      53.040162
# std       4.61305         5.753965        71.727126      86.045090
# min    2000.00000        57.500000        13.000000       1.000000
# 25%    2003.75000        66.675000        84.000000       4.000000
# 50%    2007.50000        72.700000       135.000000      17.000000
# 75%    2011.25000        74.900000       189.000000      65.250000
# max    2015.00000        87.000000       274.000000     359.000000
#
#           alcohol  percentage_expenditure  hepatitis_b      measles  \
# count  704.000000              704.000000   704.000000   704.000000
# mean     1.930099              221.109056    86.552572   988.579545
# std      2.341334              302.213655    13.365703  1386.939469
# min      0.010000                0.000000    61.000000     0.000000
# 25%      0.170000                6.060366    77.133333     9.750000
# 50%      1.160000               63.813282    93.500000   140.000000
# 75%      2.622500              283.449078    98.000000  1822.750000
# max     12.010000              854.011576    99.000000  3526.000000
#
#        under-five_deaths       polio  total_expenditure  diphtheria  \
# count         704.000000  704.000000         704.000000  704.000000
# mean           63.930359   89.026989           5.015824   89.149148
# std           104.865844   11.618062           2.038664   11.053944
# min             1.000000   65.000000           1.170000   67.000000
# 25%             4.000000   82.000000           3.437500   81.750000
# 50%            17.500000   95.000000           4.600000   95.000000
# 75%            82.250000   98.000000           6.450000   98.000000
# max           433.000000   99.000000           9.220000   99.000000
#
#          hiv/aids           gdp    population  thinness_10-19_years  \
# count  704.000000    704.000000  7.040000e+02            704.000000
# mean     0.119602   5755.992561  1.625642e+07              7.236790
# std      0.039727   7367.062914  2.036595e+07              5.679741
# min      0.100000      1.681350  3.400000e+01              0.900000
# 25%      0.100000    649.026499  3.750692e+05              2.800000
# 50%      0.100000   2612.889313  7.695446e+06              5.150000
# 75%      0.100000   7222.171917  2.360550e+07             11.000000
# max      0.200000  23573.628400  6.251023e+07             19.900000
#
#        thinness_5-9_years  income_composition_of_resources   schooling
# count          704.000000                       704.000000  704.000000
# mean             7.504830                         0.663050   11.810937
# std              5.841289                         0.136311    2.094002
# min              1.000000                         0.381000    7.300000
# 25%              3.000000                         0.572750   10.500000
# 50%              5.100000                         0.674500   12.000000
# 75%             11.200000                         0.765250   13.300000
# max             21.300000                         0.924000   16.000000

# %%
wins_df.describe(include='O')
# Out:
#             country      status
# count           704         704
# unique           44           2
# top     Afghanistan  Developing
# freq             16         656

# %%
plt.figure(figsize=(15, 20))
for i, col in enumerate(cont_vars, 1):
    plt.subplot(5, 4, i)
    plt.hist(wins_df[col])
    plt.title(col)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
wins_df.status.value_counts().plot(kind='bar')
plt.title('Count of Rows by Country Status')
plt.xlabel('Country Status')
plt.ylabel('Count of Rows')
plt.xticks(rotation=0)

plt.subplot(122)
wins_df.status.value_counts().plot(kind='pie', autopct='%.2f')
plt.ylabel('')
plt.title('Country Status Pie Chart')
# Out:
# Text(0.5, 1.0, 'Country Status Pie Chart')

# %%
wins_df[cont_vars].corr()
# Out:
#                                  life_expectancy  adult_mortality  \
# life_expectancy                         1.000000        -0.668083
# adult_mortality                        -0.668083         1.000000
# infant_deaths                          -0.179499         0.002817
# alcohol                                 0.251504        -0.035530
# percentage_expenditure                  0.520586        -0.352725
# hepatitis_b                             0.490708        -0.259633
# measles                                -0.260064         0.158989
# under-five_deaths                      -0.193710         0.012375
# polio                                   0.570258        -0.300139
# total_expenditure                       0.117259         0.005126
# diphtheria                              0.559754        -0.286662
# hiv/aids                               -0.371531         0.243539
# gdp                                     0.514174        -0.357912
# population                             -0.035268        -0.060584
# thinness_10-19_years                   -0.372382         0.167444
# thinness_5-9_years                     -0.408824         0.222578
# income_composition_of_resources         0.828708        -0.543366
# schooling                               0.771083        -0.459633
#
#                                  infant_deaths   alcohol  \
# life_expectancy                      -0.179499  0.251504
# adult_mortality                       0.002817 -0.035530
# infant_deaths                         1.000000 -0.082037
# alcohol                              -0.082037  1.000000
# percentage_expenditure               -0.127492  0.182700
# hepatitis_b                          -0.288256  0.101548
# measles                               0.500781  0.026633
# under-five_deaths                     0.991749 -0.074720
# polio                                -0.297655  0.207770
# total_expenditure                    -0.194843  0.107733
# diphtheria                           -0.302433  0.221714
# hiv/aids                              0.093837 -0.057692
# gdp                                  -0.142424  0.121564
# population                            0.225425 -0.171434
# thinness_10-19_years                  0.331033 -0.342091
# thinness_5-9_years                    0.358686 -0.301982
# income_composition_of_resources      -0.217040  0.274468
# schooling                            -0.367948  0.306109
#
#                                  percentage_expenditure  hepatitis_b  \
# life_expectancy                                0.520586     0.490708
# adult_mortality                               -0.352725    -0.259633
# infant_deaths                                 -0.127492    -0.288256
# alcohol                                        0.182700     0.101548
# percentage_expenditure                         1.000000     0.339421
# hepatitis_b                                    0.339421     1.000000
# measles                                       -0.218769    -0.392398
# under-five_deaths                             -0.136527    -0.310368
# polio                                          0.329620     0.791061
# total_expenditure                             -0.098270     0.018549
# diphtheria                                     0.326621     0.802364
# hiv/aids                                      -0.247909    -0.158767
# gdp                                            0.751586     0.277409
# population                                     0.054606    -0.055334
# thinness_10-19_years                          -0.262289    -0.226793
# thinness_5-9_years                            -0.292623    -0.270100
# income_composition_of_resources                0.532224     0.518226
# schooling                                      0.485329     0.580863
#
#                                   measles  under-five_deaths     polio  \
# life_expectancy                 -0.260064          -0.193710  0.570258
# adult_mortality                  0.158989           0.012375 -0.300139
# infant_deaths                    0.500781           0.991749 -0.297655
# alcohol                          0.026633          -0.074720  0.207770
# percentage_expenditure          -0.218769          -0.136527  0.329620
# hepatitis_b                     -0.392398          -0.310368  0.791061
# measles                          1.000000           0.512216 -0.352585
# under-five_deaths                0.512216           1.000000 -0.316509
# polio                           -0.352585          -0.316509  1.000000
# total_expenditure               -0.082228          -0.190710 -0.004735
# diphtheria                      -0.351979          -0.322409  0.922135
# hiv/aids                         0.169865           0.088920 -0.189456
# gdp                             -0.251003          -0.154994  0.270058
# population                       0.159180           0.226035 -0.093189
# thinness_10-19_years             0.263318           0.339136 -0.273102
# thinness_5-9_years               0.293469           0.369754 -0.313387
# income_composition_of_resources -0.292494          -0.235561  0.563395
# schooling                       -0.353525          -0.393731  0.604592
#
#                                  total_expenditure  diphtheria  hiv/aids  \
# life_expectancy                           0.117259    0.559754 -0.371531
# adult_mortality                           0.005126   -0.286662  0.243539
# infant_deaths                            -0.194843   -0.302433  0.093837
# alcohol                                   0.107733    0.221714 -0.057692
# percentage_expenditure                   -0.098270    0.326621 -0.247909
# hepatitis_b                               0.018549    0.802364 -0.158767
# measles                                  -0.082228   -0.351979  0.169865
# under-five_deaths                        -0.190710   -0.322409  0.088920
# polio                                    -0.004735    0.922135 -0.189456
# total_expenditure                         1.000000    0.028340 -0.080501
# diphtheria                                0.028340    1.000000 -0.184178
# hiv/aids                                 -0.080501   -0.184178  1.000000
# gdp                                      -0.060713    0.261546 -0.243820
# population                               -0.302228   -0.086870  0.123732
# thinness_10-19_years                     -0.021908   -0.277874  0.305581
# thinness_5-9_years                       -0.040444   -0.313032  0.312338
# income_composition_of_resources           0.031335    0.558240 -0.392626
# schooling                                 0.161400    0.612220 -0.312937
#
#                                       gdp  population  thinness_10-19_years  \
# life_expectancy                  0.514174   -0.035268             -0.372382
# adult_mortality                 -0.357912   -0.060584              0.167444
# infant_deaths                   -0.142424    0.225425              0.331033
# alcohol                          0.121564   -0.171434             -0.342091
# percentage_expenditure           0.751586    0.054606             -0.262289
# hepatitis_b                      0.277409   -0.055334             -0.226793
# measles                         -0.251003    0.159180              0.263318
# under-five_deaths               -0.154994    0.226035              0.339136
# polio                            0.270058   -0.093189             -0.273102
# total_expenditure               -0.060713   -0.302228             -0.021908
# diphtheria                       0.261546   -0.086870             -0.277874
# hiv/aids                        -0.243820    0.123732              0.305581
# gdp                              1.000000    0.159156             -0.267677
# population                       0.159156    1.000000              0.147305
# thinness_10-19_years            -0.267677    0.147305              1.000000
# thinness_5-9_years              -0.302184    0.145426              0.893796
# income_composition_of_resources  0.547085    0.023284             -0.522199
# schooling                        0.466501   -0.066138             -0.494506
#
#                                  thinness_5-9_years  \
# life_expectancy                           -0.408824
# adult_mortality                            0.222578
# infant_deaths                              0.358686
# alcohol                                   -0.301982
# percentage_expenditure                    -0.292623
# hepatitis_b                               -0.270100
# measles                                    0.293469
# under-five_deaths                          0.369754
# polio                                     -0.313387
# total_expenditure                         -0.040444
# diphtheria                                -0.313032
# hiv/aids                                   0.312338
# gdp                                       -0.302184
# population                                 0.145426
# thinness_10-19_years                       0.893796
# thinness_5-9_years                         1.000000
# income_composition_of_resources           -0.539935
# schooling                                 -0.512410
#
#                                  income_composition_of_resources  schooling
# life_expectancy                                         0.828708   0.771083
# adult_mortality                                        -0.543366  -0.459633
# infant_deaths                                          -0.217040  -0.367948
# alcohol                                                 0.274468   0.306109
# percentage_expenditure                                  0.532224   0.485329
# hepatitis_b                                             0.518226   0.580863
# measles                                                -0.292494  -0.353525
# under-five_deaths                                      -0.235561  -0.393731
# polio                                                   0.563395   0.604592
# total_expenditure                                       0.031335   0.161400
# diphtheria                                              0.558240   0.612220
# hiv/aids                                               -0.392626  -0.312937
# gdp                                                     0.547085   0.466501
# population                                              0.023284  -0.066138
# thinness_10-19_years                                   -0.522199  -0.494506
# thinness_5-9_years                                     -0.539935  -0.512410
# income_composition_of_resources                         1.000000   0.834949
# schooling                                               0.834949   1.000000

# %%
mask = np.triu(wins_df[cont_vars].corr())
plt.figure(figsize=(15,6))
sns.heatmap(wins_df[cont_vars].corr(), annot=True, fmt='.2g', vmin=-1, vmax=1, center=0, cmap='coolwarm', mask=mask)
plt.ylim(18, 0)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
sns.lineplot('year', 'life_expectancy', data=wins_df, marker='o')
plt.title('Life Expectancy by Year')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
