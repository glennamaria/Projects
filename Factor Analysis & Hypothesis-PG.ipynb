# %% [markdown]
# <a href="https://colab.research.google.com/github/glennamaria/task1/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/Life Expectancy Data.csv"
df= pd.read_csv(path)
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print(df.columns)
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# country                              0
# year                                 0
# status                               0
# life_expectancy                     10
# adult_mortality                     10
# infant_deaths                        0
# alcohol                            194
# percentage_expenditure               0
# hepatitis_b                        553
# measles                              0
# bmi                                 34
# under-five_deaths                    0
# polio                               19
# total_expenditure                  226
# diphtheria                          19
# hiv/aids                             0
# gdp                                448
# population                         652
# thinness__1-19_years                34
# thinness_5-9_years                  34
# income_composition_of_resources    167
# schooling                          163
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#           country  year      status  life_expectancy  adult_mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant_deaths  alcohol  percentage_expenditure  hepatitis_b  measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  polio  total_expenditure  diphtheria  hiv/aids         gdp  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358878
#
#       population  thinness__1-19_years  thinness_5-9_years  \
# 0     33736494.0                  17.2                17.3
# 1       327582.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2933  12777511.0                   9.4                 9.4
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
# 2937  12222251.0                  11.0                11.2
#
#       income_composition_of_resources  schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [1649 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# country                            0
# year                               0
# status                             0
# life_expectancy                    0
# adult_mortality                    0
# infant_deaths                      0
# alcohol                            0
# percentage_expenditure             0
# hepatitis_b                        0
# measles                            0
# bmi                                0
# under-five_deaths                  0
# polio                              0
# total_expenditure                  0
# diphtheria                         0
# hiv/aids                           0
# gdp                                0
# population                         0
# thinness__1-19_years               0
# thinness_5-9_years                 0
# income_composition_of_resources    0
# schooling                          0
# dtype: int64

# %%
df1=df.copy()
df1.to_csv('cleaned.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          1649 non-null   object
#  1   year                             1649 non-null   int64
#  2   status                           1649 non-null   object
#  3   life_expectancy                  1649 non-null   float64
#  4   adult_mortality                  1649 non-null   float64
#  5   infant_deaths                    1649 non-null   int64
#  6   alcohol                          1649 non-null   float64
#  7   percentage_expenditure           1649 non-null   float64
#  8   hepatitis_b                      1649 non-null   float64
#  9   measles                          1649 non-null   int64
#  10  bmi                              1649 non-null   float64
#  11  under-five_deaths                1649 non-null   int64
#  12  polio                            1649 non-null   float64
#  13  total_expenditure                1649 non-null   float64
#  14  diphtheria                       1649 non-null   float64
#  15  hiv/aids                         1649 non-null   float64
#  16  gdp                              1649 non-null   float64
#  17  population                       1649 non-null   float64
#  18  thinness__1-19_years             1649 non-null   float64
#  19  thinness_5-9_years               1649 non-null   float64
#  20  income_composition_of_resources  1649 non-null   float64
#  21  schooling                        1649 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 296.3+ KB

# %%
columns_dict={'life_expectancy': 1, 'adult_mortality': 2, 'infant_deaths': 3, 'alcohol': 4, 
                   'percentage_expenditure': 5, 'hepatitis_b': 6, 'measles': 7, 'bmi': 8, 'under-five_deaths': 9, 
                   'polio': 10, 'total_expenditure': 11, 'diphtheria': 12, 'hiv/aids': 13, 'gdp': 14, 'population': 15, 
                   'thinness__1-19_years': 16, 'thinness_5-9_years': 17, 'income_composition_of_resources': 18, 
                   'schooling':19}             
plt.figure(figsize=(20,30))
for variable,i in columns_dict.items():
  plt.subplot(5,4,i)
  plt.boxplot(df[variable])
  plt.title(variable)

plt.show()

# %%
df.describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count  1649.000000      1649.000000      1649.000000    1649.000000
# mean   2007.840509        69.302304       168.215282      32.553062
# std       4.087711         8.796834       125.310417     120.847190
# min    2000.000000        44.000000         1.000000       0.000000
# 25%    2005.000000        64.400000        77.000000       1.000000
# 50%    2008.000000        71.700000       148.000000       3.000000
# 75%    2011.000000        75.000000       227.000000      22.000000
# max    2015.000000        89.000000       723.000000    1600.000000
#
#            alcohol  percentage_expenditure  hepatitis_b        measles  \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# min       0.010000                0.000000     2.000000       0.000000
# 25%       0.810000               37.438577    74.000000       0.000000
# 50%       3.790000              145.102253    89.000000      15.000000
# 75%       7.340000              509.389994    96.000000     373.000000
# max      17.870000            18961.348600    99.000000  131441.000000
#
#                bmi  under-five_deaths        polio  total_expenditure  \
# count  1649.000000        1649.000000  1649.000000        1649.000000
# mean     38.128623          44.220133    83.564585           5.955925
# std      19.754249         162.897999    22.450557           2.299385
# min       2.000000           0.000000     3.000000           0.740000
# 25%      19.500000           1.000000    81.000000           4.410000
# 50%      43.700000           4.000000    93.000000           5.840000
# 75%      55.800000          29.000000    97.000000           7.470000
# max      77.100000        2100.000000    99.000000          14.390000
#
#         diphtheria     hiv/aids            gdp    population  \
# count  1649.000000  1649.000000    1649.000000  1.649000e+03
# mean     84.155246     1.983869    5566.031887  1.465363e+07
# std      21.579193     6.032360   11475.900117  7.046039e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      82.000000     0.100000     462.149650  1.918970e+05
# 50%      92.000000     0.100000    1592.572182  1.419631e+06
# 75%      97.000000     0.700000    4718.512910  7.658972e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        thinness__1-19_years  thinness_5-9_years  \
# count           1649.000000         1649.000000
# mean               4.850637            4.907762
# std                4.599228            4.653757
# min                0.100000            0.100000
# 25%                1.600000            1.700000
# 50%                3.000000            3.200000
# 75%                7.100000            7.100000
# max               27.200000           28.200000
#
#        income_composition_of_resources    schooling
# count                      1649.000000  1649.000000
# mean                          0.631551    12.119891
# std                           0.183089     2.795388
# min                           0.000000     4.200000
# 25%                           0.509000    10.300000
# 50%                           0.673000    12.300000
# 75%                           0.751000    14.000000
# max                           0.936000    20.700000

# %%
def outlier_count(col, data=df):
    print(15*'-' + col + 15*'-')
    q75, q25 = np.percentile(data[col], [75, 25])
    iqr = q75 - q25
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    print('Number of outliers: {}'.format(outlier_count))
    print('Percent of data that is outlier: {}%'.format(outlier_percent))
for col in columns_dict:
    outlier_count(col)
# Out:
# ---------------life_expectancy---------------
# Number of outliers: 39
# Percent of data that is outlier: 2.37%
# ---------------adult_mortality---------------
# Number of outliers: 54
# Percent of data that is outlier: 3.27%
# ---------------infant_deaths---------------
# Number of outliers: 199
# Percent of data that is outlier: 12.07%
# ---------------alcohol---------------
# Number of outliers: 2
# Percent of data that is outlier: 0.12%
# ---------------percentage_expenditure---------------
# Number of outliers: 187
# Percent of data that is outlier: 11.34%
# ---------------hepatitis_b---------------
# Number of outliers: 165
# Percent of data that is outlier: 10.01%
# ---------------measles---------------
# Number of outliers: 297
# Percent of data that is outlier: 18.01%
# ---------------bmi---------------
# Number of outliers: 0
# Percent of data that is outlier: 0.0%
# ---------------under-five_deaths---------------
# Number of outliers: 222
# Percent of data that is outlier: 13.46%
# ---------------polio---------------
# Number of outliers: 142
# Percent of data that is outlier: 8.61%
# ---------------total_expenditure---------------
# Number of outliers: 7
# Percent of data that is outlier: 0.42%
# ---------------diphtheria---------------
# Number of outliers: 134
# Percent of data that is outlier: 8.13%
# ---------------hiv/aids---------------
# Number of outliers: 299
# Percent of data that is outlier: 18.13%
# ---------------gdp---------------
# Number of outliers: 208
# Percent of data that is outlier: 12.61%
# ---------------population---------------
# Number of outliers: 233
# Percent of data that is outlier: 14.13%
# ---------------thinness__1-19_years---------------
# Number of outliers: 77
# Percent of data that is outlier: 4.67%
# ---------------thinness_5-9_years---------------
# Number of outliers: 78
# Percent of data that is outlier: 4.73%
# ---------------income_composition_of_resources---------------
# Number of outliers: 48
# Percent of data that is outlier: 2.91%
# ---------------schooling---------------
# Number of outliers: 16
# Percent of data that is outlier: 0.97%

# %%
for variable in columns_dict.keys():
    q75, q25 = np.percentile(df[variable], [75 ,25])
    iqr = q75 - q25

    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    print("Number of outliers and percentage of it in {} : {} and {}".format(variable,
                                                                             len((np.where((df[variable] > max_val) | 
                                                                                           (df[variable] < min_val))[0])),len((np.where((df[variable] > max_val) | 
                                                                                           (df[variable] < min_val))[0]))*100/1987))
# Out:
# Number of outliers and percentage of it in life_expectancy : 39 and 1.9627579265223956
# Number of outliers and percentage of it in adult_mortality : 54 and 2.7176648213387016
# Number of outliers and percentage of it in infant_deaths : 199 and 10.015098137896326
# Number of outliers and percentage of it in alcohol : 2 and 0.10065425264217413
# Number of outliers and percentage of it in percentage_expenditure : 187 and 9.411172622043281
# Number of outliers and percentage of it in hepatitis_b : 165 and 8.303975842979366
# Number of outliers and percentage of it in measles : 297 and 14.947156517362858
# Number of outliers and percentage of it in bmi : 0 and 0.0
# Number of outliers and percentage of it in under-five_deaths : 222 and 11.17262204328133
# Number of outliers and percentage of it in polio : 142 and 7.146451937594363
# Number of outliers and percentage of it in total_expenditure : 7 and 0.3522898842476095
# Number of outliers and percentage of it in diphtheria : 134 and 6.743834927025667
# Number of outliers and percentage of it in hiv/aids : 299 and 15.047810770005032
# Number of outliers and percentage of it in gdp : 208 and 10.468042274786109
# Number of outliers and percentage of it in population : 233 and 11.726220432813287
# Number of outliers and percentage of it in thinness__1-19_years : 77 and 3.875188726723704
# Number of outliers and percentage of it in thinness_5-9_years : 78 and 3.925515853044791
# Number of outliers and percentage of it in income_composition_of_resources : 48 and 2.415702063412179
# Number of outliers and percentage of it in schooling : 16 and 0.8052340211373931

# %%
df.describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count  1649.000000      1649.000000      1649.000000    1649.000000
# mean   2007.840509        69.302304       168.215282      32.553062
# std       4.087711         8.796834       125.310417     120.847190
# min    2000.000000        44.000000         1.000000       0.000000
# 25%    2005.000000        64.400000        77.000000       1.000000
# 50%    2008.000000        71.700000       148.000000       3.000000
# 75%    2011.000000        75.000000       227.000000      22.000000
# max    2015.000000        89.000000       723.000000    1600.000000
#
#            alcohol  percentage_expenditure  hepatitis_b        measles  \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# min       0.010000                0.000000     2.000000       0.000000
# 25%       0.810000               37.438577    74.000000       0.000000
# 50%       3.790000              145.102253    89.000000      15.000000
# 75%       7.340000              509.389994    96.000000     373.000000
# max      17.870000            18961.348600    99.000000  131441.000000
#
#                bmi  under-five_deaths        polio  total_expenditure  \
# count  1649.000000        1649.000000  1649.000000        1649.000000
# mean     38.128623          44.220133    83.564585           5.955925
# std      19.754249         162.897999    22.450557           2.299385
# min       2.000000           0.000000     3.000000           0.740000
# 25%      19.500000           1.000000    81.000000           4.410000
# 50%      43.700000           4.000000    93.000000           5.840000
# 75%      55.800000          29.000000    97.000000           7.470000
# max      77.100000        2100.000000    99.000000          14.390000
#
#         diphtheria     hiv/aids            gdp    population  \
# count  1649.000000  1649.000000    1649.000000  1.649000e+03
# mean     84.155246     1.983869    5566.031887  1.465363e+07
# std      21.579193     6.032360   11475.900117  7.046039e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      82.000000     0.100000     462.149650  1.918970e+05
# 50%      92.000000     0.100000    1592.572182  1.419631e+06
# 75%      97.000000     0.700000    4718.512910  7.658972e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        thinness__1-19_years  thinness_5-9_years  \
# count           1649.000000         1649.000000
# mean               4.850637            4.907762
# std                4.599228            4.653757
# min                0.100000            0.100000
# 25%                1.600000            1.700000
# 50%                3.000000            3.200000
# 75%                7.100000            7.100000
# max               27.200000           28.200000
#
#        income_composition_of_resources    schooling
# count                      1649.000000  1649.000000
# mean                          0.631551    12.119891
# std                           0.183089     2.795388
# min                           0.000000     4.200000
# 25%                           0.509000    10.300000
# 50%                           0.673000    12.300000
# 75%                           0.751000    14.000000
# max                           0.936000    20.700000

# %%
all_col = ['life_expectancy','adult_mortality','infant_deaths',
         'alcohol','percentage_expenditure','hepatitis_b',
         'under-five_deaths','polio','total_expenditure',
         'diphtheria','gdp',
         'population','thinness__1-19_years','thinness_5-9_years',
         'income_composition_of_resources',
         'schooling']

plt.figure(figsize=(15,75))

for i in range(len(all_col)):
    plt.subplot(18,2,i+1)
    plt.hist(df[all_col[i]])
    plt.title(all_col[i])

plt.show()

# %%
df_skew = df.drop('year', axis = 1)

print(df_skew.skew())
# Out:
# life_expectancy                    -0.628758
# adult_mortality                     1.276429
# infant_deaths                       8.477369
# alcohol                             0.662518
# percentage_expenditure              4.980574
# hepatitis_b                        -1.793377
# measles                             7.957838
# bmi                                -0.233601
# under-five_deaths                   8.340863
# polio                              -2.360177
# total_expenditure                   0.213362
# diphtheria                         -2.487492
# hiv/aids                            4.974176
# gdp                                 4.517297
# population                         14.186299
# thinness__1-19_years                1.821074
# thinness_5-9_years                  1.866980
# income_composition_of_resources    -1.155244
# schooling                          -0.128164
# dtype: float64

# %%
print(df_skew.kurt())
# Out:
# life_expectancy                      0.040321
# adult_mortality                      2.400945
# infant_deaths                       85.319969
# alcohol                             -0.591100
# percentage_expenditure              30.992195
# hepatitis_b                          2.231415
# measles                             74.671440
# bmi                                 -1.270226
# under-five_deaths                   82.187221
# polio                                5.063551
# total_expenditure                   -0.010253
# diphtheria                           5.855639
# hiv/aids                            27.751492
# gdp                                 28.015318
# population                         230.164461
# thinness__1-19_years                 4.159346
# thinness_5-9_years                   4.519833
# income_composition_of_resources      2.061192
# schooling                            0.045708
# dtype: float64

# %%
df.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
needed1= df.drop(['country','year','status'], axis=1)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(needed1.corr(), annot=True)

# %%
df4=needed1.drop(['life_expectancy'], axis=1)

# %%
# !pip install factor_analyzer==0.2.3
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value,p_value=calculate_bartlett_sphericity(df4)
chi_square_value, p_value
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: factor_analyzer==0.2.3 in /usr/local/lib/python3.8/dist-packages (0.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from factor_analyzer==0.2.3) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from factor_analyzer==0.2.3) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from factor_analyzer==0.2.3) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->factor_analyzer==0.2.3) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->factor_analyzer==0.2.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->factor_analyzer==0.2.3) (1.15.0)
# (25764.314130838673, 0.0)

# %%
from factor_analyzer import FactorAnalyzer
fa = FactorAnalyzer()
fa.analyze(df4,16, rotation=None)

ev, v = fa.get_eigenvalues()
ev
# Out:
#     Original_Eigenvalues
# 0               5.541837
# 1               2.779679
# 2               1.840680
# 3               1.496183
# 4               1.183052
# 5               0.877362
# 6               0.793800
# 7               0.658736
# 8               0.523713
# 9               0.512200
# 10              0.418448
# 11              0.383610
# 12              0.347517
# 13              0.331164
# 14              0.199853
# 15              0.070857
# 16              0.038889
# 17              0.002420

# %%
fa = FactorAnalyzer()
fa.analyze(df4, 5, rotation="varimax")
fa.loadings
# Out:
#                                   Factor1   Factor2   Factor3   Factor4  \
# adult_mortality                 -0.254474 -0.028083 -0.121766 -0.133926
# infant_deaths                   -0.188340  0.974498 -0.118145 -0.022586
# alcohol                          0.560289  0.046561  0.199740  0.345987
# percentage_expenditure           0.219896 -0.039144  0.014603  0.917431
# hepatitis_b                      0.058711 -0.165404  0.654251 -0.032026
# measles                         -0.063150  0.503061 -0.058231 -0.046115
# bmi                              0.611919 -0.110399  0.097480  0.096159
# under-five_deaths               -0.191196  0.959439 -0.135410 -0.020605
# polio                            0.161092 -0.047436  0.677455  0.074510
# total_expenditure                0.242774 -0.094581  0.115179  0.136628
# diphtheria                       0.152717 -0.045454  0.819993  0.065353
# hiv/aids                        -0.087354 -0.012161 -0.057906 -0.009033
# gdp                              0.247997 -0.036986  0.043503  0.940158
# population                      -0.070343  0.666409 -0.013525  0.018946
# thinness__1-19_years            -0.815483  0.340738  0.009721 -0.020925
# thinness_5-9_years              -0.797584  0.341491  0.008472 -0.021289
# income_composition_of_resources  0.615226  0.048289  0.290723  0.304726
# schooling                        0.659028 -0.014155  0.317113  0.323717
#
#                                   Factor5
# adult_mortality                  0.737567
# infant_deaths                    0.003226
# alcohol                          0.044013
# percentage_expenditure          -0.081857
# hepatitis_b                     -0.049416
# measles                         -0.012019
# bmi                             -0.234474
# under-five_deaths                0.022850
# polio                           -0.081433
# total_expenditure                0.055322
# diphtheria                      -0.067311
# hiv/aids                         0.704090
# gdp                             -0.094031
# population                      -0.033901
# thinness__1-19_years             0.117108
# thinness_5-9_years               0.135209
# income_composition_of_resources -0.268121
# schooling                       -0.217430

# %%
fa.get_factor_variance()
# Out:
#                  Factor1   Factor2   Factor3   Factor4   Factor5
# SS Loadings     3.177210  2.861406  1.863444  2.104025  1.281857
# Proportion Var  0.176512  0.158967  0.103525  0.116890  0.071214
# Cumulative Var  0.176512  0.335479  0.439003  0.555894  0.627108

# %%
df.describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count  1649.000000      1649.000000      1649.000000    1649.000000
# mean   2007.840509        69.302304       168.215282      32.553062
# std       4.087711         8.796834       125.310417     120.847190
# min    2000.000000        44.000000         1.000000       0.000000
# 25%    2005.000000        64.400000        77.000000       1.000000
# 50%    2008.000000        71.700000       148.000000       3.000000
# 75%    2011.000000        75.000000       227.000000      22.000000
# max    2015.000000        89.000000       723.000000    1600.000000
#
#            alcohol  percentage_expenditure  hepatitis_b        measles  \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# min       0.010000                0.000000     2.000000       0.000000
# 25%       0.810000               37.438577    74.000000       0.000000
# 50%       3.790000              145.102253    89.000000      15.000000
# 75%       7.340000              509.389994    96.000000     373.000000
# max      17.870000            18961.348600    99.000000  131441.000000
#
#                bmi  under-five_deaths        polio  total_expenditure  \
# count  1649.000000        1649.000000  1649.000000        1649.000000
# mean     38.128623          44.220133    83.564585           5.955925
# std      19.754249         162.897999    22.450557           2.299385
# min       2.000000           0.000000     3.000000           0.740000
# 25%      19.500000           1.000000    81.000000           4.410000
# 50%      43.700000           4.000000    93.000000           5.840000
# 75%      55.800000          29.000000    97.000000           7.470000
# max      77.100000        2100.000000    99.000000          14.390000
#
#         diphtheria     hiv/aids            gdp    population  \
# count  1649.000000  1649.000000    1649.000000  1.649000e+03
# mean     84.155246     1.983869    5566.031887  1.465363e+07
# std      21.579193     6.032360   11475.900117  7.046039e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      82.000000     0.100000     462.149650  1.918970e+05
# 50%      92.000000     0.100000    1592.572182  1.419631e+06
# 75%      97.000000     0.700000    4718.512910  7.658972e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        thinness__1-19_years  thinness_5-9_years  \
# count           1649.000000         1649.000000
# mean               4.850637            4.907762
# std                4.599228            4.653757
# min                0.100000            0.100000
# 25%                1.600000            1.700000
# 50%                3.000000            3.200000
# 75%                7.100000            7.100000
# max               27.200000           28.200000
#
#        income_composition_of_resources    schooling
# count                      1649.000000  1649.000000
# mean                          0.631551    12.119891
# std                           0.183089     2.795388
# min                           0.000000     4.200000
# 25%                           0.509000    10.300000
# 50%                           0.673000    12.300000
# 75%                           0.751000    14.000000
# max                           0.936000    20.700000

# %%
df1=df[['country','life_expectancy', 'status', 'year']]
df1.head()
# Out:
#        country  life_expectancy      status  year
# 0  Afghanistan             65.0  Developing  2015
# 1  Afghanistan             59.9  Developing  2014
# 2  Afghanistan             59.9  Developing  2013
# 3  Afghanistan             59.5  Developing  2012
# 4  Afghanistan             59.2  Developing  2011

# %%
df1['status'] = df1.status.map({'Developing': 0, 'Developed': 1})
print(df1.head())
df1['status']= df1['status'].astype(int)
print(df1)
# Out:
#        country  life_expectancy  status  year
# 0  Afghanistan             65.0       0  2015
# 1  Afghanistan             59.9       0  2014
# 2  Afghanistan             59.9       0  2013
# 3  Afghanistan             59.5       0  2012
# 4  Afghanistan             59.2       0  2011
#           country  life_expectancy  status  year
# 0     Afghanistan             65.0       0  2015
# 1     Afghanistan             59.9       0  2014
# 2     Afghanistan             59.9       0  2013
# 3     Afghanistan             59.5       0  2012
# 4     Afghanistan             59.2       0  2011
# ...           ...              ...     ...   ...
# 2933     Zimbabwe             44.3       0  2004
# 2934     Zimbabwe             44.5       0  2003
# 2935     Zimbabwe             44.8       0  2002
# 2936     Zimbabwe             45.3       0  2001
# 2937     Zimbabwe             46.0       0  2000
#
# [1649 rows x 4 columns]

# %%
df5=df1.groupby(['country', 'status'])['life_expectancy'].mean()
df5
# Out:
# country      status
# Afghanistan  0         58.193750
# Albania      0         75.156250
# Algeria      0         74.209091
# Angola       0         50.675000
# Argentina    0         75.238462
#                          ...
# Uruguay      0         76.013333
# Uzbekistan   0         68.046154
# Vanuatu      0         71.346667
# Zambia       0         57.250000
# Zimbabwe     0         49.386667
# Name: life_expectancy, Length: 133, dtype: float64

# %%
df5.to_csv("hypothesis.csv")
df5 = pd.read_csv("hypothesis.csv")
df5.head()
# Out:
#        country  status  life_expectancy
# 0  Afghanistan       0        58.193750
# 1      Albania       0        75.156250
# 2      Algeria       0        74.209091
# 3       Angola       0        50.675000
# 4    Argentina       0        75.238462

# %%
df5['status'].value_counts()
# Out:
# 0    114
# 1     19
# Name: status, dtype: int64

# %%
developing = df5.loc[df5.status == 0]
developing.head()
# Out:
#        country  status  life_expectancy
# 0  Afghanistan       0        58.193750
# 1      Albania       0        75.156250
# 2      Algeria       0        74.209091
# 3       Angola       0        50.675000
# 4    Argentina       0        75.238462

# %%
developed = df5.loc[df5.status == 1]
developed.head()
# Out:
#       country  status  life_expectancy
# 6   Australia       1        81.907143
# 7     Austria       1        81.480000
# 11    Belgium       1        80.653333
# 18   Bulgaria       1        72.740000
# 32    Croatia       1        76.787500

# %%
from scipy.stats import normaltest

stat1, p1 = normaltest(developed['life_expectancy'])



print(stat1, p1)
# Out:
# 3.6257144311888156 0.1631872090252597

# %%
from scipy.stats import normaltest

stat1, p1 = normaltest(developing['life_expectancy'])



print(stat1, p1)
# Out:
# 7.174208646599567 0.027678362082604664

# %%
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
qqplot(developing['life_expectancy'], line='s')
plt.show()

# %%
mean_developing = developing['life_expectancy'].mean()
mean_developed = developed['life_expectancy'].mean()

print(f"The mean life expectancy of developing countries: {mean_developing}")
print(f"The mean life expectancy of developed countries: {mean_developed}")

s1 = developing['life_expectancy'].std()
s2 = developed['life_expectancy'].std()


n1 = developing['life_expectancy'].count()
n2 = developed['life_expectancy'].count()
print(f"S1 is: {s1} while s2 is: {s2}")
print("..............")
import math


sp = math.sqrt(((n1-1)*s1**2+(n2-1)*s2**2)/(n1+n2-2)) 

print(f"The pooled estimate of the commom stdev is: {round(sp,3)}, which is a value between {round(s1,3)} and {round(s2,3)}")
# Out:
# The mean life expectancy of developing countries: 66.87999662374662
# The mean life expectancy of developed countries: 79.07138471177946
# S1 is: 8.252666782671978 while s2 is: 3.579831596232734
# ..............
# The pooled estimate of the commom stdev is: 7.779, which is a value between 8.253 and 3.58

# %%
z = (mean_developing-mean_developed)/(sp*math.sqrt((1/n1)+(1/n2)))
z
# Out:
# -6.324784780199424

# %%
from scipy import stats
from statsmodels.stats import weightstats as stests

# computing the z_test and p-value
ztest ,pval1 = stests.ztest(developing['life_expectancy'], developed['life_expectancy'], value=0,alternative='two-sided')
print(ztest, pval1)
if pval1 < 0.05:
    print("reject null hypothesis and accept the alternate hypothesis")
else:
    print("accept null hypothesis")
# Out:
# -6.324784780199424 2.535857715167202e-10
# reject null hypothesis and accept the alternate hypothesis

# %%
diff = mean_developed-mean_developing
diff
# Out:
# 12.191388088032838
